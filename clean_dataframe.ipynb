# %%
# Import dependencies
import pandas as pd
#hello

# %%
# Loading csv into pandas
data = pd.read_csv("data.csv")
data
# Out:
#      State or Territory  Industry division         Sex    Age group  \
# 0          0. Australia  0. All industries  0. Persons  0. All ages
# 1          0. Australia  0. All industries  0. Persons  1. Under 20
# 2          0. Australia  0. All industries  0. Persons     2. 20-29
# 3          0. Australia  0. All industries  0. Persons     3. 30-39
# 4          0. Australia  0. All industries  0. Persons     4. 40-49
# ...                 ...                ...         ...          ...
# 4322                NaN                NaN         NaN          NaN
# 4323                NaN                NaN         NaN          NaN
# 4324                NaN                NaN         NaN          NaN
# 4325                NaN                NaN         NaN          NaN
# 4326                NaN                NaN         NaN          NaN
#
#                 4-Jan-20  11-Jan-20  18-Jan-20  25-Jan-20  1-Feb-20  8-Feb-20  \
# ...

# %%
#data = data.dropna()
data['Age group'].unique()
# Out:
# array(['0. All ages', '1. Under 20', '2. 20-29', '3. 30-39', '4. 40-49',
#        '5. 50-59', '6. 60-69', '7. 70 and over', nan], dtype=object)

# %%
# Renaming elements in dataframe

data["State or Territory"] = data["State or Territory"].replace({
    "0. Australia":"Australia",
    "1. NSW":"NSW",
    "2. VIC":"VIC",
    "3. QLD":"QLD",
    "4. SA":"SA",
    "5. WA":"WA",
    "6. TAS":"TAS",
    "7. NT":"NT",
    "8. ACT":"ACT"
})

data["Industry division"] = data["Industry division"].replace({
    "0. All industries":"All Industries",
    "01. A-Agriculture, forestry & fishing":"Agriculture, forestry & fishing",
    "02. B-Mining":"Mining",
    "03. C-Manufacturing":"Manufacturing",
    "04. D-Electricity, gas, water & waste services":"Electricity, gas, water & waste services",
    "05. E-Construction":"Construction",
    "06. F-Wholesale trade":"Wholesale trade",
    "07. G-Retail trade":"Retail trade",
    "08. H-Accommodation & food services":"Accommodation & food services",
    "09. I-Transport, postal & warehousing":"Transport, postal & warehousing",
    "10. J-Information media & telecommunications":"Information media & telecommunications",
    "11. K-Financial & insurance services":"Financial & insurance services",
    "12. L-Rental, hiring & real estate services":"Rental, hiring & real estate services",
    "13. M-Professional, scientific & technical services":"Professional, scientific & technical services",
    "14. N-Administrative & support services":"Administrative & support services",
    "15. O-Public administration & safety":"Public administration & safety",
    "16. P-Education & training":"Education & training",
    "17. Q-Health care & social assistance":"Health care & social assistance",
    "18. R-Arts & recreation services":"Arts & recreation services",
    "19. S-Other services":"Other services"  
})

data["Sex"] = data["Sex"].replace({
    "0. Persons":"Other",
    "1. Males":"Males",
    "2. Females":"Females"
})

data["Age group"] = data["Age group"].replace({
    "0. All ages":"All ages",
    "1. Under 20":"Under 20",
    "2. 20-29":"20-29",
    "3. 30-39":"30-39",
    "4. 40-49":"40-49",
    "5. 50-59":"50-59",
    "6. 60-69":"60-69",
    "7. 70 and over":"70 and over"
})

# %%
data = data.dropna()
data
# Out:
#      State or Territory           Industry division      Sex Age group  \
# 0             Australia              All Industries    Other  All ages
# 1             Australia              All Industries    Other  Under 20
# 2             Australia              All Industries    Other     20-29
# 3             Australia              All Industries    Other     30-39
# 4             Australia              All Industries    Other     40-49
# ...                 ...                         ...      ...       ...
# 4280                ACT  Arts & recreation services    Males  All ages
# 4288                ACT  Arts & recreation services  Females  All ages
# 4296                ACT              Other services    Other  All ages
# 4304                ACT              Other services    Males  All ages
# 4312                ACT              Other services  Females  All ages
#
#      4-Jan-20  11-Jan-20  18-Jan-20  25-Jan-20  1-Feb-20  8-Feb-20  ...  \
# ...

# %%
victoria_df=data.loc[data["State or Territory"]=="VIC"]
victoria_df
# Out:
#      State or Territory           Industry division      Sex Age group  \
# 960                 VIC              All Industries    Other  All ages
# 961                 VIC              All Industries    Other  Under 20
# 962                 VIC              All Industries    Other     20-29
# 963                 VIC              All Industries    Other     30-39
# 964                 VIC              All Industries    Other     40-49
# ...                 ...                         ...      ...       ...
# 1400                VIC  Arts & recreation services    Males  All ages
# 1408                VIC  Arts & recreation services  Females  All ages
# 1416                VIC              Other services    Other  All ages
# 1424                VIC              Other services    Males  All ages
# 1432                VIC              Other services  Females  All ages
#
#      4-Jan-20  11-Jan-20  18-Jan-20  25-Jan-20  1-Feb-20  8-Feb-20  ...  \
# ...

# %%
victoria_all_industries_df=data.loc[data["State or Territory"]=="VIC"]
victoria_all_industries_df

# %%
data_Industry_df=data.copy()

# %%
data_Industry_df
# Out:
#      State or Territory           Industry division      Sex Age group  \
# 0             Australia              All Industries    Other  All ages
# 1             Australia              All Industries    Other  Under 20
# 2             Australia              All Industries    Other     20-29
# 3             Australia              All Industries    Other     30-39
# 4             Australia              All Industries    Other     40-49
# ...                 ...                         ...      ...       ...
# 4280                ACT  Arts & recreation services    Males  All ages
# 4288                ACT  Arts & recreation services  Females  All ages
# 4296                ACT              Other services    Other  All ages
# 4304                ACT              Other services    Males  All ages
# 4312                ACT              Other services  Females  All ages
#
#      4-Jan-20  11-Jan-20  18-Jan-20  25-Jan-20  1-Feb-20  8-Feb-20  ...  \
# ...

# %%
data.columns
# Out:
# Index(['State or Territory', 'Industry division', 'Sex', 'Age group',
#        '4-Jan-20', '11-Jan-20', '18-Jan-20', '25-Jan-20', '1-Feb-20',
#        '8-Feb-20', '15-Feb-20', '22-Feb-20', '29-Feb-20', '7-Mar-20',
#        '14-Mar-20', '21-Mar-20', '28-Mar-20', '4-Apr-20', '11-Apr-20',
#        '18-Apr-20', '25-Apr-20', '2-May-20', '9-May-20', '16-May-20',
#        '23-May-20', '30-May-20', '6-Jun-20', '13-Jun-20', '20-Jun-20',
#        '27-Jun-20', '4-Jul-20', '11-Jul-20', '18-Jul-20', '25-Jul-20',
#        '1-Aug-20', '8-Aug-20', '15-Aug-20', '22-Aug-20', '29-Aug-20',
#        '5-Sep-20'],
#       dtype='object')

# %%
data_Industry_df.dtypes
data_Industry_df['4-Jan-20']=data_Industry_df['4-Jan-20'].astype(float)

# %%
data_Industry_df["Sum of Jan"]=data_Industry_df["4-Jan-20"]+data_Industry_df["11-Jan-20"]+data_Industry_df["18-Jan-20"]+data_Industry_df["25-Jan-20"]
data_Industry_df["Sum of Feb"]=data_Industry_df["1-Feb-20"]+data_Industry_df["8-Feb-20"]+data_Industry_df["15-Feb-20"]+data_Industry_df["22-Feb-20"]+data_Industry_df["29-Feb-20"]
data_Industry_df["Sum of March"]=data_Industry_df["7-Mar-20"]+data_Industry_df["14-Mar-20"]+data_Industry_df["21-Mar-20"]+data_Industry_df["28-Mar-20"]

# %%
All_industries=pd.DataFrame(data_Industry_df.groupby("Industry division").sum()).reset_index()
All_industries[All_industries["Industry division"]=="All Industries"]
All_industries=pd.DataFrame(data_Industry_df.groupby("State or Territory").sum()).reset_index()
All_industries
# Out:
#   State or Territory  4-Jan-20  11-Jan-20  18-Jan-20  25-Jan-20  1-Feb-20  \
# 0                ACT    7457.9     7668.6     7863.7     7898.2    7942.9
# 1          Australia   19639.3    20236.3    20602.6    20799.5   20925.5
# 2                NSW    7558.5     7748.9     7852.3     7919.0    7974.0
# 3                 NT    7508.6     7642.5     7743.5     7841.1    7914.7
# 4                QLD    7490.5     7758.8     7870.1     7929.6    7956.5
# 5                 SA    7503.7     7726.6     7844.8     7903.1    7919.1
# 6                TAS    7697.8     7901.9     7978.8     8019.4    8073.5
# 7                VIC    7493.0     7665.0     7827.3     7906.3    7956.1
# 8                 WA    7637.2     7830.3     7906.4     7931.8    7946.2
#
#    8-Feb-20  15-Feb-20  22-Feb-20  29-Feb-20  ...  25-Jul-20  1-Aug-20  \
# 0    8052.3     8124.5     8104.2     8086.3  ...     7786.0    7779.0
# 1   21118.3    21202.9    21235.1    21216.7  ...    20512.8   20514.2
# ...

# %%
#Investigate how covid-19 has impacted single touch payroll in Australia.
#has single touch payroll reduced over time?
#1.Read the csv files
#2.Group the weekly data by month
#3.get the total amount of wages by month
#4.then get the %change for each moth for payroll as well as covid19 cases
#5.compare the two  data (maybe create a table which has the 2 data sets after %change calculation)
#6.plot the graphs

# %%
#create a data frame that has only the all industries
all_industry_data_df = pd.DataFrame({
    "State or Territory":["Australia","NSW","VIC","QLD","SA","WA","TAS","NT","ACT"],
    "Industry Division":["All Industries","All Industries","All Industries","All Industries","All Industries","All Industries","All Industries","All Industries","All Industries"]})


all_industry_data_df.head()
# Out:
#   State or Territory Industry Division
# 0          Australia    All Industries
# 1                NSW    All Industries
# 2                VIC    All Industries
# 3                QLD    All Industries
# 4                 SA    All Industries

# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Loading csv into pandas
data = pd.read_csv("data.csv")
data
# Out:
#      State or Territory  Industry division         Sex    Age group  \
# 0          0. Australia  0. All industries  0. Persons  0. All ages
# 1          0. Australia  0. All industries  0. Persons  1. Under 20
# 2          0. Australia  0. All industries  0. Persons     2. 20-29
# 3          0. Australia  0. All industries  0. Persons     3. 30-39
# 4          0. Australia  0. All industries  0. Persons     4. 40-49
# ...                 ...                ...         ...          ...
# 4322                NaN                NaN         NaN          NaN
# 4323                NaN                NaN         NaN          NaN
# 4324                NaN                NaN         NaN          NaN
# 4325                NaN                NaN         NaN          NaN
# 4326                NaN                NaN         NaN          NaN
#
#                 4-Jan-20  11-Jan-20  18-Jan-20  25-Jan-20  1-Feb-20  8-Feb-20  \
# 0                   92.8       95.2       96.7       97.5      98.0      98.7
# 1                   85.6       88.2       90.3       92.6      94.7      96.9
# 2                   91.3       94.1       96.1       97.1      97.5      98.1
# 3                   93.7       96.0       97.3       97.9      98.3      98.8
# 4                   93.8       95.9       97.1       97.8      98.3      98.9
# ...                  ...        ...        ...        ...       ...       ...
# 4322                 NaN        NaN        NaN        NaN       NaN       NaN
# 4323                 NaN        NaN        NaN        NaN       NaN       NaN
# 4324                 NaN        NaN        NaN        NaN       NaN       NaN
# 4325                 NaN        NaN        NaN        NaN       NaN       NaN
# 4326  NA = Not available        NaN        NaN        NaN       NaN       NaN
#
#       ...  4-Jul-20  11-Jul-20  18-Jul-20  25-Jul-20  1-Aug-20  8-Aug-20  \
# 0     ...      96.3       96.5       96.4       96.4      96.5      96.2
# 1     ...      98.2       98.8       98.5       98.7      99.0      96.8
# 2     ...      93.5       94.0       93.9       93.9      94.0      93.9
# 3     ...      96.8       97.3       97.3       97.3      97.3      97.2
# 4     ...      97.5       98.0       97.9       98.1      98.1      98.0
# ...   ...       ...        ...        ...        ...       ...       ...
# 4322  ...       NaN        NaN        NaN        NaN       NaN       NaN
# 4323  ...       NaN        NaN        NaN        NaN       NaN       NaN
# 4324  ...       NaN        NaN        NaN        NaN       NaN       NaN
# 4325  ...       NaN        NaN        NaN        NaN       NaN       NaN
# 4326  ...       NaN        NaN        NaN        NaN       NaN       NaN
#
#       15-Aug-20  22-Aug-20  29-Aug-20  5-Sep-20
# 0          96.1       95.9       95.6      95.5
# 1          96.2       96.2       96.1      97.3
# 2          93.7       93.6       93.3      93.3
# 3          97.1       96.9       96.7      96.6
# 4          97.9       97.8       97.5      97.5
# ...         ...        ...        ...       ...
# 4322        NaN        NaN        NaN       NaN
# 4323        NaN        NaN        NaN       NaN
# 4324        NaN        NaN        NaN       NaN
# 4325        NaN        NaN        NaN       NaN
# 4326        NaN        NaN        NaN       NaN
#
# [4327 rows x 40 columns]

# %%
#data = data.dropna()
data['Age group'].unique()
# Out:
# array(['0. All ages', '1. Under 20', '2. 20-29', '3. 30-39', '4. 40-49',
#        '5. 50-59', '6. 60-69', '7. 70 and over', nan], dtype=object)

# %%
# Renaming elements for easier referral in dataframe

# Removing integer in front of states
data["State or Territory"] = data["State or Territory"].replace({
    "0. Australia":"Australia",
    "1. NSW":"NSW",
    "2. VIC":"VIC",
    "3. QLD":"QLD",
    "4. SA":"SA",
    "5. WA":"WA",
    "6. TAS":"TAS",
    "7. NT":"NT",
    "8. ACT":"ACT"
})

# Removing integers in front of industries
data["Industry division"] = data["Industry division"].replace({
    "0. All industries":"All Industries",
    "01. A-Agriculture, forestry & fishing":"Agriculture, forestry & fishing",
    "02. B-Mining":"Mining",
    "03. C-Manufacturing":"Manufacturing",
    "04. D-Electricity, gas, water & waste services":"Electricity, gas, water & waste services",
    "05. E-Construction":"Construction",
    "06. F-Wholesale trade":"Wholesale trade",
    "07. G-Retail trade":"Retail trade",
    "08. H-Accommodation & food services":"Accommodation & food services",
    "09. I-Transport, postal & warehousing":"Transport, postal & warehousing",
    "10. J-Information media & telecommunications":"Information media & telecommunications",
    "11. K-Financial & insurance services":"Financial & insurance services",
    "12. L-Rental, hiring & real estate services":"Rental, hiring & real estate services",
    "13. M-Professional, scientific & technical services":"Professional, scientific & technical services",
    "14. N-Administrative & support services":"Administrative & support services",
    "15. O-Public administration & safety":"Public administration & safety",
    "16. P-Education & training":"Education & training",
    "17. Q-Health care & social assistance":"Health care & social assistance",
    "18. R-Arts & recreation services":"Arts & recreation services",
    "19. S-Other services":"Other services"  
})

# Removing integers in front of genders
data["Sex"] = data["Sex"].replace({
    "0. Persons":"Other",
    "1. Males":"Males",
    "2. Females":"Females"
})

# Removing integers in front of ages
data["Age group"] = data["Age group"].replace({
    "0. All ages":"All ages",
    "1. Under 20":"Under 20",
    "2. 20-29":"20-29",
    "3. 30-39":"30-39",
    "4. 40-49":"40-49",
    "5. 50-59":"50-59",
    "6. 60-69":"60-69",
    "7. 70 and over":"70 and over"
})

# %%
# Removing any nan values within the data frame
data = data.dropna()
data
# Out:
#      State or Territory           Industry division      Sex Age group  \
# 0             Australia              All Industries    Other  All ages
# 1             Australia              All Industries    Other  Under 20
# 2             Australia              All Industries    Other     20-29
# 3             Australia              All Industries    Other     30-39
# 4             Australia              All Industries    Other     40-49
# ...                 ...                         ...      ...       ...
# 4280                ACT  Arts & recreation services    Males  All ages
# 4288                ACT  Arts & recreation services  Females  All ages
# 4296                ACT              Other services    Other  All ages
# 4304                ACT              Other services    Males  All ages
# 4312                ACT              Other services  Females  All ages
#
#      4-Jan-20  11-Jan-20  18-Jan-20  25-Jan-20  1-Feb-20  8-Feb-20  ...  \
# 0        92.8       95.2       96.7       97.5      98.0      98.7  ...
# 1        85.6       88.2       90.3       92.6      94.7      96.9  ...
# 2        91.3       94.1       96.1       97.1      97.5      98.1  ...
# 3        93.7       96.0       97.3       97.9      98.3      98.8  ...
# 4        93.8       95.9       97.1       97.8      98.3      98.9  ...
# ...       ...        ...        ...        ...       ...       ...  ...
# 4280     89.3       93.9       96.3       91.7      93.0     101.9  ...
# 4288     85.8       91.8       95.7       94.7      96.2     103.6  ...
# 4296     94.7       96.8       99.0       99.2      99.2     100.9  ...
# 4304     97.2       99.6      101.8      101.9     101.8     102.8  ...
# 4312     93.6       95.2       97.7       97.9      97.9      99.7  ...
#
#       4-Jul-20  11-Jul-20  18-Jul-20  25-Jul-20  1-Aug-20  8-Aug-20  \
# 0         96.3       96.5       96.4       96.4      96.5      96.2
# 1         98.2       98.8       98.5       98.7      99.0      96.8
# 2         93.5       94.0       93.9       93.9      94.0      93.9
# 3         96.8       97.3       97.3       97.3      97.3      97.2
# 4         97.5       98.0       97.9       98.1      98.1      98.0
# ...        ...        ...        ...        ...       ...       ...
# 4280      86.6       89.7       90.3       91.5      92.4      93.5
# 4288      84.7       89.5       91.2       93.5      94.9      95.8
# 4296     100.6      101.9      102.1      102.4     101.5     101.4
# 4304     101.0      103.6      104.3      104.6     103.3     102.5
# 4312      99.2       99.6       99.5       99.8      99.2      99.7
#
#       15-Aug-20  22-Aug-20  29-Aug-20  5-Sep-20
# 0          96.1       95.9       95.6      95.5
# 1          96.2       96.2       96.1      97.3
# 2          93.7       93.6       93.3      93.3
# 3          97.1       96.9       96.7      96.6
# 4          97.9       97.8       97.5      97.5
# ...         ...        ...        ...       ...
# 4280       93.8       93.0       91.9      82.8
# 4288       96.5       96.7       96.6      91.9
# 4296      101.6      101.4      101.3     101.1
# 4304      102.6      102.0      102.4     101.9
# 4312      100.0       99.9       99.2      98.9
#
# [862 rows x 40 columns]

# %%
# Checking all unique industry names
data["Industry division"].unique()
# Out:
# array(['All Industries', 'Agriculture, forestry & fishing', 'Mining',
#        'Manufacturing', 'Electricity, gas, water & waste services',
#        'Construction', 'Wholesale trade', 'Retail trade',
#        'Accommodation & food services', 'Transport, postal & warehousing',
#        'Information media & telecommunications',
#        'Financial & insurance services',
#        'Rental, hiring & real estate services',
#        'Professional, scientific & technical services',
#        'Administrative & support services',
#        'Public administration & safety', 'Education & training',
#        'Health care & social assistance', 'Arts & recreation services',
#        'Other services'], dtype=object)

# %%
# Extracting data for Australia only from original dataframe
australia_df = data.loc[data['State or Territory'] == "Australia"]
australia_df
# Out:
#     State or Territory Industry division      Sex    Age group 4-Jan-20  \
# 0            Australia    All Industries    Other     All ages     92.8
# 1            Australia    All Industries    Other     Under 20     85.6
# 2            Australia    All Industries    Other        20-29     91.3
# 3            Australia    All Industries    Other        30-39     93.7
# 4            Australia    All Industries    Other        40-49     93.8
# ..                 ...               ...      ...          ...      ...
# 461          Australia    Other services    Other        50-59     92.7
# 462          Australia    Other services    Other        60-69     93.8
# 463          Australia    Other services    Other  70 and over     93.3
# 464          Australia    Other services    Males     All ages     92.8
# 472          Australia    Other services  Females     All ages     91.2
#
#      11-Jan-20  18-Jan-20  25-Jan-20  1-Feb-20  8-Feb-20  ...  4-Jul-20  \
# 0         95.2       96.7       97.5      98.0      98.7  ...      96.3
# 1         88.2       90.3       92.6      94.7      96.9  ...      98.2
# 2         94.1       96.1       97.1      97.5      98.1  ...      93.5
# 3         96.0       97.3       97.9      98.3      98.8  ...      96.8
# 4         95.9       97.1       97.8      98.3      98.9  ...      97.5
# ..         ...        ...        ...       ...       ...  ...       ...
# 461       95.4       97.1       98.4      99.1      98.8  ...      98.9
# 462       96.4       98.1       99.1      99.7      99.6  ...      97.9
# 463       95.4       97.1       98.2      99.3      98.3  ...      95.4
# 464       96.4       98.4       99.1      99.4      99.0  ...      98.3
# 472       94.0       95.8       97.0      97.9      98.3  ...      96.5
#
#      11-Jul-20  18-Jul-20  25-Jul-20  1-Aug-20  8-Aug-20  15-Aug-20  \
# 0         96.5       96.4       96.4      96.5      96.2       96.1
# 1         98.8       98.5       98.7      99.0      96.8       96.2
# 2         94.0       93.9       93.9      94.0      93.9       93.7
# 3         97.3       97.3       97.3      97.3      97.2       97.1
# 4         98.0       97.9       98.1      98.1      98.0       97.9
# ..         ...        ...        ...       ...       ...        ...
# 461       99.0       98.7       99.0      98.9      98.8       98.7
# 462       97.7       97.5       97.5      97.2      97.2       96.9
# 463       95.0       94.6       94.8      94.6      92.9       91.7
# 464       98.0       97.7       97.6      97.2      96.8       96.6
# 472       95.8       95.4       95.7      95.2      94.9       94.6
#
#      22-Aug-20  29-Aug-20  5-Sep-20
# 0         95.9       95.6      95.5
# 1         96.2       96.1      97.3
# 2         93.6       93.3      93.3
# 3         96.9       96.7      96.6
# 4         97.8       97.5      97.5
# ..         ...        ...       ...
# 461       97.8       97.4      97.6
# 462       95.8       95.6      95.8
# 463       90.3       90.1      89.5
# 464       95.8       95.3      94.9
# 472       93.9       93.5      93.3
#
# [214 rows x 40 columns]

# %%
# Extracting data for all industries in Australia from original dataframe
australia_all_industries = australia_df.loc[australia_df["Industry division"] == "All Industries"]
australia_all_industries
# Out:
#    State or Territory Industry division      Sex    Age group 4-Jan-20  \
# 0           Australia    All Industries    Other     All ages     92.8
# 1           Australia    All Industries    Other     Under 20     85.6
# 2           Australia    All Industries    Other        20-29     91.3
# 3           Australia    All Industries    Other        30-39     93.7
# 4           Australia    All Industries    Other        40-49     93.8
# 5           Australia    All Industries    Other        50-59     94.2
# 6           Australia    All Industries    Other        60-69     94.3
# 7           Australia    All Industries    Other  70 and over     91.2
# 8           Australia    All Industries    Males     All ages     92.9
# 9           Australia    All Industries    Males     Under 20     87.4
# 10          Australia    All Industries    Males        20-29     90.7
# 11          Australia    All Industries    Males        30-39       94
# 12          Australia    All Industries    Males        40-49     94.3
# 13          Australia    All Industries    Males        50-59     94.1
# 14          Australia    All Industries    Males        60-69     93.5
# 15          Australia    All Industries    Males  70 and over     90.5
# 16          Australia    All Industries  Females     All ages     93.5
# 17          Australia    All Industries  Females     Under 20     90.3
# 18          Australia    All Industries  Females        20-29     92.9
# 19          Australia    All Industries  Females        30-39     94.1
# 20          Australia    All Industries  Females        40-49     93.5
# 21          Australia    All Industries  Females        50-59     94.4
# 22          Australia    All Industries  Females        60-69     95.1
# 23          Australia    All Industries  Females  70 and over     92.1
#
#     11-Jan-20  18-Jan-20  25-Jan-20  1-Feb-20  8-Feb-20  ...  4-Jul-20  \
# 0        95.2       96.7       97.5      98.0      98.7  ...      96.3
# 1        88.2       90.3       92.6      94.7      96.9  ...      98.2
# 2        94.1       96.1       97.1      97.5      98.1  ...      93.5
# 3        96.0       97.3       97.9      98.3      98.8  ...      96.8
# 4        95.9       97.1       97.8      98.3      98.9  ...      97.5
# 5        96.4       97.7       98.3      98.7      99.2  ...      97.5
# 6        96.4       97.5       98.2      98.7      99.3  ...      95.7
# 7        93.2       94.2       95.7      97.1      98.5  ...      92.6
# 8        96.0       97.7       98.4      98.6      99.1  ...      95.8
# 9        90.5       92.7       94.6      96.5      98.5  ...      97.3
# 10       94.4       96.7       97.6      97.9      98.5  ...      93.6
# 11       96.8       98.4       98.9      99.0      99.2  ...      96.0
# 12       96.9       98.2       98.8      98.9      99.2  ...      96.8
# 13       96.8       98.2       98.7      98.9      99.3  ...      96.9
# 14       96.3       97.7       98.4      98.8      99.4  ...      95.2
# 15       92.6       94.0       95.5      97.0      98.5  ...      92.7
# 16       95.3       96.5       97.3      98.0      98.8  ...      96.6
# 17       92.0       93.8       95.6      97.3      99.2  ...      94.3
# 18       94.8       96.5       97.4      97.8      98.4  ...      93.7
# 19       95.7       96.7       97.4      97.9      98.6  ...      97.4
# 20       95.1       96.1       96.9      97.7      98.6  ...      98.2
# 21       96.2       97.2       98.0      98.6      99.2  ...      98.1
# 22       96.5       97.3       98.0      98.6      99.3  ...      96.2
# 23       93.9       94.5       95.9      97.2      98.5  ...      92.3
#
#     11-Jul-20  18-Jul-20  25-Jul-20  1-Aug-20  8-Aug-20  15-Aug-20  22-Aug-20  \
# 0        96.5       96.4       96.4      96.5      96.2       96.1       95.9
# 1        98.8       98.5       98.7      99.0      96.8       96.2       96.2
# 2        94.0       93.9       93.9      94.0      93.9       93.7       93.6
# 3        97.3       97.3       97.3      97.3      97.2       97.1       96.9
# 4        98.0       97.9       98.1      98.1      98.0       97.9       97.8
# 5        97.8       97.8       97.9      98.0      97.9       97.8       97.6
# 6        95.3       95.0       95.1      95.1      94.9       94.7       94.4
# 7        91.1       90.4       90.5      90.6      89.9       89.8       89.5
# 8        96.3       96.2       96.2      96.1      95.8       95.6       95.5
# 9        97.2       96.6       96.5      96.5      94.3       93.5       93.4
# 10       94.2       93.9       93.9      93.9      93.8       93.5       93.6
# 11       96.9       96.9       96.9      96.7      96.5       96.4       96.3
# 12       97.7       97.7       97.8      97.7      97.5       97.4       97.3
# 13       97.7       97.7       97.9      97.8      97.6       97.5       97.4
# 14       95.3       95.1       95.2      95.1      94.9       94.8       94.6
# 15       91.4       90.8       91.0      91.1      90.3       90.1       89.8
# 16       96.5       96.3       96.4      96.5      96.3       96.1       95.9
# 17       94.8       94.3       94.4      94.4      92.2       91.5       91.3
# 18       94.1       94.1       94.0      94.1      94.0       93.9       93.7
# 19       97.6       97.5       97.5      97.6      97.6       97.5       97.3
# 20       98.1       98.0       98.3      98.5      98.4       98.3       98.2
# 21       97.9       97.8       98.0      98.2      98.1       98.0       97.8
# 22       95.3       94.9       94.9      95.1      94.8       94.7       94.3
# 23       90.7       89.7       89.8      90.0      89.4       89.4       89.0
#
#     29-Aug-20  5-Sep-20
# 0        95.6      95.5
# 1        96.1      97.3
# 2        93.3      93.3
# 3        96.7      96.6
# 4        97.5      97.5
# 5        97.3      97.4
# 6        94.2      94.2
# 7        89.3      88.9
# 8        95.1      95.0
# 9        93.0      94.0
# 10       93.2      93.3
# 11       96.0      95.8
# 12       97.0      96.8
# 13       97.1      97.0
# 14       94.2      94.1
# 15       89.7      89.3
# 16       95.7      95.7
# 17       91.0      91.9
# 18       93.5      93.4
# 19       97.1      97.1
# 20       98.0      98.2
# 21       97.6      97.8
# 22       94.1      94.4
# 23       88.9      88.5
#
# [24 rows x 40 columns]

# %%
# Combining industry division, gender and age group into a single group column
australia_df["Group"] = australia_df["Industry division"] + "_" + australia_df["Sex"] + "_" + australia_df["Age group"]
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Replacing the age group with combined groups
australia_df["Age group"] = australia_df["Group"]
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
australia_df
# Out:
#     State or Territory Industry division      Sex  \
# 0            Australia    All Industries    Other
# 1            Australia    All Industries    Other
# 2            Australia    All Industries    Other
# 3            Australia    All Industries    Other
# 4            Australia    All Industries    Other
# ..                 ...               ...      ...
# 461          Australia    Other services    Other
# 462          Australia    Other services    Other
# 463          Australia    Other services    Other
# 464          Australia    Other services    Males
# 472          Australia    Other services  Females
#
#                             Age group 4-Jan-20  11-Jan-20  18-Jan-20  \
# 0       All Industries_Other_All ages     92.8       95.2       96.7
# 1       All Industries_Other_Under 20     85.6       88.2       90.3
# 2          All Industries_Other_20-29     91.3       94.1       96.1
# 3          All Industries_Other_30-39     93.7       96.0       97.3
# 4          All Industries_Other_40-49     93.8       95.9       97.1
# ..                                ...      ...        ...        ...
# 461        Other services_Other_50-59     92.7       95.4       97.1
# 462        Other services_Other_60-69     93.8       96.4       98.1
# 463  Other services_Other_70 and over     93.3       95.4       97.1
# 464     Other services_Males_All ages     92.8       96.4       98.4
# 472   Other services_Females_All ages     91.2       94.0       95.8
#
#      25-Jan-20  1-Feb-20  8-Feb-20  ...  11-Jul-20  18-Jul-20  25-Jul-20  \
# 0         97.5      98.0      98.7  ...       96.5       96.4       96.4
# 1         92.6      94.7      96.9  ...       98.8       98.5       98.7
# 2         97.1      97.5      98.1  ...       94.0       93.9       93.9
# 3         97.9      98.3      98.8  ...       97.3       97.3       97.3
# 4         97.8      98.3      98.9  ...       98.0       97.9       98.1
# ..         ...       ...       ...  ...        ...        ...        ...
# 461       98.4      99.1      98.8  ...       99.0       98.7       99.0
# 462       99.1      99.7      99.6  ...       97.7       97.5       97.5
# 463       98.2      99.3      98.3  ...       95.0       94.6       94.8
# 464       99.1      99.4      99.0  ...       98.0       97.7       97.6
# 472       97.0      97.9      98.3  ...       95.8       95.4       95.7
#
#      1-Aug-20  8-Aug-20  15-Aug-20  22-Aug-20  29-Aug-20  5-Sep-20  \
# 0        96.5      96.2       96.1       95.9       95.6      95.5
# 1        99.0      96.8       96.2       96.2       96.1      97.3
# 2        94.0      93.9       93.7       93.6       93.3      93.3
# 3        97.3      97.2       97.1       96.9       96.7      96.6
# 4        98.1      98.0       97.9       97.8       97.5      97.5
# ..        ...       ...        ...        ...        ...       ...
# 461      98.9      98.8       98.7       97.8       97.4      97.6
# 462      97.2      97.2       96.9       95.8       95.6      95.8
# 463      94.6      92.9       91.7       90.3       90.1      89.5
# 464      97.2      96.8       96.6       95.8       95.3      94.9
# 472      95.2      94.9       94.6       93.9       93.5      93.3
#
#                                 Group
# 0       All Industries_Other_All ages
# 1       All Industries_Other_Under 20
# 2          All Industries_Other_20-29
# 3          All Industries_Other_30-39
# 4          All Industries_Other_40-49
# ..                                ...
# 461        Other services_Other_50-59
# 462        Other services_Other_60-69
# 463  Other services_Other_70 and over
# 464     Other services_Males_All ages
# 472   Other services_Females_All ages
#
# [214 rows x 41 columns]

# %%
# Removing individual unwanted columns
del australia_df["State or Territory"]

# %%
# Removing individual unwanted columns
del australia_df["Industry division"]

# %%
# Removing individual unwanted columns
del australia_df["Sex"]

# %%
# Removing individual unwanted columns
del australia_df["Group"]

# %%
# Renaming combined column into groups
australia_df = australia_df.rename(columns={
    "Age group":"Group"
})

# %%
australia_df
# Out:
#                                 Group 4-Jan-20  11-Jan-20  18-Jan-20  \
# 0       All Industries_Other_All ages     92.8       95.2       96.7
# 1       All Industries_Other_Under 20     85.6       88.2       90.3
# 2          All Industries_Other_20-29     91.3       94.1       96.1
# 3          All Industries_Other_30-39     93.7       96.0       97.3
# 4          All Industries_Other_40-49     93.8       95.9       97.1
# ..                                ...      ...        ...        ...
# 461        Other services_Other_50-59     92.7       95.4       97.1
# 462        Other services_Other_60-69     93.8       96.4       98.1
# 463  Other services_Other_70 and over     93.3       95.4       97.1
# 464     Other services_Males_All ages     92.8       96.4       98.4
# 472   Other services_Females_All ages     91.2       94.0       95.8
#
#      25-Jan-20  1-Feb-20  8-Feb-20  15-Feb-20  22-Feb-20  29-Feb-20  ...  \
# 0         97.5      98.0      98.7       99.2       99.3       99.3  ...
# 1         92.6      94.7      96.9       98.2       96.9       96.0  ...
# 2         97.1      97.5      98.1       98.7       99.0       99.1  ...
# 3         97.9      98.3      98.8       99.3       99.4       99.5  ...
# 4         97.8      98.3      98.9       99.3       99.4       99.4  ...
# ..         ...       ...       ...        ...        ...        ...  ...
# 461       98.4      99.1      98.8       99.1       99.6      100.2  ...
# 462       99.1      99.7      99.6       99.6       99.8      100.3  ...
# 463       98.2      99.3      98.3       97.8       97.8       97.9  ...
# 464       99.1      99.4      99.0       99.3       99.5      100.2  ...
# 472       97.0      97.9      98.3       98.9       99.5      100.2  ...
#
#      4-Jul-20  11-Jul-20  18-Jul-20  25-Jul-20  1-Aug-20  8-Aug-20  15-Aug-20  \
# 0        96.3       96.5       96.4       96.4      96.5      96.2       96.1
# 1        98.2       98.8       98.5       98.7      99.0      96.8       96.2
# 2        93.5       94.0       93.9       93.9      94.0      93.9       93.7
# 3        96.8       97.3       97.3       97.3      97.3      97.2       97.1
# 4        97.5       98.0       97.9       98.1      98.1      98.0       97.9
# ..        ...        ...        ...        ...       ...       ...        ...
# 461      98.9       99.0       98.7       99.0      98.9      98.8       98.7
# 462      97.9       97.7       97.5       97.5      97.2      97.2       96.9
# 463      95.4       95.0       94.6       94.8      94.6      92.9       91.7
# 464      98.3       98.0       97.7       97.6      97.2      96.8       96.6
# 472      96.5       95.8       95.4       95.7      95.2      94.9       94.6
#
#      22-Aug-20  29-Aug-20  5-Sep-20
# 0         95.9       95.6      95.5
# 1         96.2       96.1      97.3
# 2         93.6       93.3      93.3
# 3         96.9       96.7      96.6
# 4         97.8       97.5      97.5
# ..         ...        ...       ...
# 461       97.8       97.4      97.6
# 462       95.8       95.6      95.8
# 463       90.3       90.1      89.5
# 464       95.8       95.3      94.9
# 472       93.9       93.5      93.3
#
# [214 rows x 37 columns]

# %%
# Checking transposed data
australia_df.T.head()
# Out:
#                                      0                              1    \
# Group      All Industries_Other_All ages  All Industries_Other_Under 20
# 4-Jan-20                            92.8                           85.6
# 11-Jan-20                           95.2                           88.2
# 18-Jan-20                           96.7                           90.3
# 25-Jan-20                           97.5                           92.6
#
#                                   2                           3    \
# Group      All Industries_Other_20-29  All Industries_Other_30-39
# 4-Jan-20                         91.3                        93.7
# 11-Jan-20                        94.1                          96
# 18-Jan-20                        96.1                        97.3
# 25-Jan-20                        97.1                        97.9
#
#                                   4                           5    \
# Group      All Industries_Other_40-49  All Industries_Other_50-59
# 4-Jan-20                         93.8                        94.2
# 11-Jan-20                        95.9                        96.4
# 18-Jan-20                        97.1                        97.7
# 25-Jan-20                        97.8                        98.3
#
#                                   6                                 7    \
# Group      All Industries_Other_60-69  All Industries_Other_70 and over
# 4-Jan-20                         94.3                              91.2
# 11-Jan-20                        96.4                              93.2
# 18-Jan-20                        97.5                              94.2
# 25-Jan-20                        98.2                              95.7
#
#                                      8                              9    ...  \
# Group      All Industries_Males_All ages  All Industries_Males_Under 20  ...
# 4-Jan-20                            92.9                           87.4  ...
# 11-Jan-20                             96                           90.5  ...
# 18-Jan-20                           97.7                           92.7  ...
# 25-Jan-20                           98.4                           94.6  ...
#
#                                      456                            457  \
# Group      Other services_Other_All ages  Other services_Other_Under 20
# 4-Jan-20                            91.4                           75.1
# 11-Jan-20                           94.7                           83.2
# 18-Jan-20                           96.7                           88.4
# 25-Jan-20                           97.7                           91.3
#
#                                   458                         459  \
# Group      Other services_Other_20-29  Other services_Other_30-39
# 4-Jan-20                         90.8                          93
# 11-Jan-20                        94.6                          96
# 18-Jan-20                        96.8                        97.6
# 25-Jan-20                        97.3                        98.6
#
#                                   460                         461  \
# Group      Other services_Other_40-49  Other services_Other_50-59
# 4-Jan-20                         92.3                        92.7
# 11-Jan-20                        94.8                        95.4
# 18-Jan-20                        96.4                        97.1
# 25-Jan-20                        97.7                        98.4
#
#                                   462                               463  \
# Group      Other services_Other_60-69  Other services_Other_70 and over
# 4-Jan-20                         93.8                              93.3
# 11-Jan-20                        96.4                              95.4
# 18-Jan-20                        98.1                              97.1
# 25-Jan-20                        99.1                              98.2
#
#                                      464                              472
# Group      Other services_Males_All ages  Other services_Females_All ages
# 4-Jan-20                            92.8                             91.2
# 11-Jan-20                           96.4                               94
# 18-Jan-20                           98.4                             95.8
# 25-Jan-20                           99.1                               97
#
# [5 rows x 214 columns]

# %%
# Creating a transposed dataframe of Australia data
australia_df_t = australia_df.T

# %%
# Cleaning transposed dataframe
# Grabing the first row for the header
new_header = australia_df_t.iloc[0]

# Taking the data less the header row
australia_df_t = australia_df_t[1:] 

# Setting the header row as the df header
australia_df_t.columns = new_header

# %%
australia_df_t.head()
# Out:
# Group     All Industries_Other_All ages All Industries_Other_Under 20  \
# 4-Jan-20                           92.8                          85.6
# 11-Jan-20                          95.2                          88.2
# 18-Jan-20                          96.7                          90.3
# 25-Jan-20                          97.5                          92.6
# 1-Feb-20                             98                          94.7
#
# Group     All Industries_Other_20-29 All Industries_Other_30-39  \
# 4-Jan-20                        91.3                       93.7
# 11-Jan-20                       94.1                         96
# 18-Jan-20                       96.1                       97.3
# 25-Jan-20                       97.1                       97.9
# 1-Feb-20                        97.5                       98.3
#
# Group     All Industries_Other_40-49 All Industries_Other_50-59  \
# 4-Jan-20                        93.8                       94.2
# 11-Jan-20                       95.9                       96.4
# 18-Jan-20                       97.1                       97.7
# 25-Jan-20                       97.8                       98.3
# 1-Feb-20                        98.3                       98.7
#
# Group     All Industries_Other_60-69 All Industries_Other_70 and over  \
# 4-Jan-20                        94.3                             91.2
# 11-Jan-20                       96.4                             93.2
# 18-Jan-20                       97.5                             94.2
# 25-Jan-20                       98.2                             95.7
# 1-Feb-20                        98.7                             97.1
#
# Group     All Industries_Males_All ages All Industries_Males_Under 20  ...  \
# 4-Jan-20                           92.9                          87.4  ...
# 11-Jan-20                            96                          90.5  ...
# 18-Jan-20                          97.7                          92.7  ...
# 25-Jan-20                          98.4                          94.6  ...
# 1-Feb-20                           98.6                          96.5  ...
#
# Group     Other services_Other_All ages Other services_Other_Under 20  \
# 4-Jan-20                           91.4                          75.1
# 11-Jan-20                          94.7                          83.2
# 18-Jan-20                          96.7                          88.4
# 25-Jan-20                          97.7                          91.3
# 1-Feb-20                           98.3                          93.4
#
# Group     Other services_Other_20-29 Other services_Other_30-39  \
# 4-Jan-20                        90.8                         93
# 11-Jan-20                       94.6                         96
# 18-Jan-20                       96.8                       97.6
# 25-Jan-20                       97.3                       98.6
# 1-Feb-20                        97.8                       98.7
#
# Group     Other services_Other_40-49 Other services_Other_50-59  \
# 4-Jan-20                        92.3                       92.7
# 11-Jan-20                       94.8                       95.4
# 18-Jan-20                       96.4                       97.1
# 25-Jan-20                       97.7                       98.4
# 1-Feb-20                        98.6                       99.1
#
# Group     Other services_Other_60-69 Other services_Other_70 and over  \
# 4-Jan-20                        93.8                             93.3
# 11-Jan-20                       96.4                             95.4
# 18-Jan-20                       98.1                             97.1
# 25-Jan-20                       99.1                             98.2
# 1-Feb-20                        99.7                             99.3
#
# Group     Other services_Males_All ages Other services_Females_All ages
# 4-Jan-20                           92.8                            91.2
# 11-Jan-20                          96.4                              94
# 18-Jan-20                          98.4                            95.8
# 25-Jan-20                          99.1                              97
# 1-Feb-20                           99.4                            97.9
#
# [5 rows x 214 columns]

# %%
# Filtering by elements check
australia_df_t.columns.str.contains("Male") & australia_df_t.columns.str.contains("Female")
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False])

# %%
# Filtering data by elements, replace a and b with desired elements
# add & australia_df_t.columns.str.contains(c) for additional filtering
a = "All Industries"
b = "All ages"
filter_df = australia_df_t.loc[:, (australia_df_t.columns.str.contains(a) & australia_df_t.columns.str.contains(b))]
filter_df["All Industries_Other_All ages"] = pd.to_numeric(filter_df["All Industries_Other_All ages"])
filter_df.dtypes
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Group
# All Industries_Other_All ages      float64
# All Industries_Males_All ages       object
# All Industries_Females_All ages     object
# dtype: object

# %%
filter_df["All Industries_Other_All ages"] = pd.to_numeric(filter_df["All Industries_Other_All ages"])
filter_df["All Industries_Males_All ages"] = pd.to_numeric(filter_df["All Industries_Males_All ages"])
filter_df["All Industries_Females_All ages"] = pd.to_numeric(filter_df["All Industries_Females_All ages"])
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
filter_df
# Out:
# Group      All Industries_Other_All ages  All Industries_Males_All ages  \
# 4-Jan-20                            92.8                           92.9
# 11-Jan-20                           95.2                           96.0
# 18-Jan-20                           96.7                           97.7
# 25-Jan-20                           97.5                           98.4
# 1-Feb-20                            98.0                           98.6
# 8-Feb-20                            98.7                           99.1
# 15-Feb-20                           99.2                           99.4
# 22-Feb-20                           99.3                           99.5
# 29-Feb-20                           99.3                           99.4
# 7-Mar-20                            99.8                           99.9
# 14-Mar-20                          100.0                          100.0
# 21-Mar-20                           99.3                           99.4
# 28-Mar-20                           96.3                           97.0
# 4-Apr-20                            93.7                           95.1
# 11-Apr-20                           91.9                           93.8
# 18-Apr-20                           91.5                           93.5
# 25-Apr-20                           91.8                           93.7
# 2-May-20                            92.2                           93.9
# 9-May-20                            92.7                           94.2
# 16-May-20                           93.3                           94.6
# 23-May-20                           93.6                           94.7
# 30-May-20                           94.1                           95.0
# 6-Jun-20                            95.0                           95.6
# 13-Jun-20                           95.5                           95.8
# 20-Jun-20                           95.7                           95.7
# 27-Jun-20                           95.6                           95.1
# 4-Jul-20                            96.3                           95.8
# 11-Jul-20                           96.5                           96.3
# 18-Jul-20                           96.4                           96.2
# 25-Jul-20                           96.4                           96.2
# 1-Aug-20                            96.5                           96.1
# 8-Aug-20                            96.2                           95.8
# 15-Aug-20                           96.1                           95.6
# 22-Aug-20                           95.9                           95.5
# 29-Aug-20                           95.6                           95.1
# 5-Sep-20                            95.5                           95.0
#
# Group      All Industries_Females_All ages
# 4-Jan-20                              93.5
# 11-Jan-20                             95.3
# 18-Jan-20                             96.5
# 25-Jan-20                             97.3
# 1-Feb-20                              98.0
# 8-Feb-20                              98.8
# 15-Feb-20                             99.3
# 22-Feb-20                             99.4
# 29-Feb-20                             99.3
# 7-Mar-20                              99.8
# 14-Mar-20                            100.0
# 21-Mar-20                             99.2
# 28-Mar-20                             95.9
# 4-Apr-20                              92.7
# 11-Apr-20                             90.7
# 18-Apr-20                             90.2
# 25-Apr-20                             90.6
# 2-May-20                              91.2
# 9-May-20                              91.9
# 16-May-20                             92.5
# 23-May-20                             93.0
# 30-May-20                             93.6
# 6-Jun-20                              94.7
# 13-Jun-20                             95.3
# 20-Jun-20                             95.7
# 27-Jun-20                             96.1
# 4-Jul-20                              96.6
# 11-Jul-20                             96.5
# 18-Jul-20                             96.3
# 25-Jul-20                             96.4
# 1-Aug-20                              96.5
# 8-Aug-20                              96.3
# 15-Aug-20                             96.1
# 22-Aug-20                             95.9
# 29-Aug-20                             95.7
# 5-Sep-20                              95.7

# %%
x_axis = np.arange(len(filter_df["All Industries_Other_All ages"]))
x_axis
plt.figure(figsize=((10,10)))
plt.plot(x_axis, filter_df["All Industries_Other_All ages"], marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4,label="Other")
plt.plot(x_axis, filter_df["All Industries_Males_All ages"], marker='', color='olive', linewidth=2,label="Males")
plt.plot(x_axis, filter_df["All Industries_Females_All ages"], marker='', color='olive', linewidth=2, linestyle='dashed', label="Females")
x_labels = ("4-Jan-20","11-Jan-20","18-Jan-20","25-Jan-20","1-Feb-20","8-Feb-20","15-Feb-20","22-Feb-20","29-Feb-20","7-Mar-20","14-Mar-20","21-Mar-20",
            "28-Mar-20","4-Apr-20","11-Apr-20","18-Apr-20","25-Apr-20","2-May-20","9-May-20","16-May-20","23-May-20","30-May-20","6-Jun-20",
            "13-Jun-20","20-Jun-20","27-Jun-20","4-Jul-20","11-Jul-20","18-Jul-20","25-Jul-20","1-Aug-20","8-Aug-20","15-Aug-20","22-Aug-20",
            "29-Aug-20","5-Sep-20")
plt.xticks(x_axis,x_labels,rotation=90)
plt.xlabel("Time")
plt.ylabel("Single Touch Payroll Index")
plt.title("Single Touch Payroll Indices across All Industries over Time by Gender")
plt.legend()

# %%
x_axis = np.arange(len(filter_df["All Industries_Other_All ages"]))
x_axis
plt.figure(figsize=((10,10)))
plt.plot(x_axis, filter_df["All Industries_Other_All ages"], marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4,label="Persons")
#plt.plot(x_axis, filter_df["All Industries_Males_All ages"], marker='', color='olive', linewidth=2,label="Males")
#plt.plot(x_axis, filter_df["All Industries_Females_All ages"], marker='', color='olive', linewidth=2, linestyle='dashed', label="Females")
x_labels = ("4-Jan-20","11-Jan-20","18-Jan-20","25-Jan-20","1-Feb-20","8-Feb-20","15-Feb-20","22-Feb-20","29-Feb-20","7-Mar-20","14-Mar-20","21-Mar-20",
            "28-Mar-20","4-Apr-20","11-Apr-20","18-Apr-20","25-Apr-20","2-May-20","9-May-20","16-May-20","23-May-20","30-May-20","6-Jun-20",
            "13-Jun-20","20-Jun-20","27-Jun-20","4-Jul-20","11-Jul-20","18-Jul-20","25-Jul-20","1-Aug-20","8-Aug-20","15-Aug-20","22-Aug-20",
            "29-Aug-20","5-Sep-20")
plt.xticks(x_axis,x_labels,rotation=90)
plt.xlabel("Time")
plt.ylabel("Single Touch Payroll Index")
plt.title("Single Touch Payroll Indices across All Industries")
plt.legend()
plt.savefig("STP.png")

# %%
a = "All Industries"
b = "Other"
c = "All ages"
filter_df = australia_df_t.loc[:, (australia_df_t.columns.str.contains(a) & australia_df_t.columns.str.contains(b) & australia_df_t.columns.str.contains(c))]
filter_df["All Industries_Other_All ages"] = pd.to_numeric(filter_df["All Industries_Other_All ages"])
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
newcol = [a for a in list(filter_df["All Industries_Other_All ages"][:-1])]
newcol.insert(0,0)
filter_df["last_val"] = newcol
filter_df["diff"] = (filter_df_2["All Industries_Other_All ages"] - filter_df["last_val"])/(filter_df["last_val"]) * 100
filter_df = filter_df.drop(["4-Jan-20","11-Jan-20","18-Jan-20","25-Jan-20","1-Feb-20","8-Feb-20","15-Feb-20","22-Feb-20","29-Feb-20","7-Mar-20"])
filter_df.to_csv("percent_change_australia.csv", index=False, header=True)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
a = "Accommodation & food services"
b = "Other"
c = "All ages"
filter_df = australia_df_t.loc[:, (australia_df_t.columns.str.contains(a) & australia_df_t.columns.str.contains(b) & australia_df_t.columns.str.contains(c))]
filter_df["Accommodation & food services_Other_All ages"] = pd.to_numeric(filter_df["Accommodation & food services_Other_All ages"])
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
newcol = [a for a in list(filter_df["Accommodation & food services_Other_All ages"][:-1])]
newcol.insert(0,0)
filter_df["last_val"] = newcol
filter_df["diff"] = (filter_df["Accommodation & food services_Other_All ages"] - filter_df["last_val"])/(filter_df["last_val"]) * 100
filter_df = filter_df.drop(["4-Jan-20","11-Jan-20","18-Jan-20","25-Jan-20","1-Feb-20","8-Feb-20","15-Feb-20","22-Feb-20","29-Feb-20","7-Mar-20"])
filter_df.to_csv("percent_change_australia_food.csv", index=False, header=True)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
# Extracting data for Australia only from original dataframe
vic_australia_df = data.loc[data['State or Territory'] == "VIC"]
vic_australia_df
# Out:
#      State or Territory           Industry division      Sex Age group  \
# 960                 VIC              All Industries    Other  All ages
# 961                 VIC              All Industries    Other  Under 20
# 962                 VIC              All Industries    Other     20-29
# 963                 VIC              All Industries    Other     30-39
# 964                 VIC              All Industries    Other     40-49
# ...                 ...                         ...      ...       ...
# 1400                VIC  Arts & recreation services    Males  All ages
# 1408                VIC  Arts & recreation services  Females  All ages
# 1416                VIC              Other services    Other  All ages
# 1424                VIC              Other services    Males  All ages
# 1432                VIC              Other services  Females  All ages
#
#      4-Jan-20  11-Jan-20  18-Jan-20  25-Jan-20  1-Feb-20  8-Feb-20  ...  \
# 960      92.2       94.3       96.2       97.3      97.9      98.7  ...
# 961      83.5       85.6       89.0       91.9      94.9      96.9  ...
# 962      90.8       93.1       95.5       96.8      97.3      98.2  ...
# 963      93.2       95.3       97.0       97.8      98.1      98.7  ...
# 964      93.2       94.9       96.4       97.4      98.0      98.7  ...
# ...       ...        ...        ...        ...       ...       ...  ...
# 1400     95.5       97.4       99.7      100.8     100.8      99.8  ...
# 1408     89.7       92.8       97.1       99.4     100.6     101.8  ...
# 1416     91.3       94.2       96.3       97.8      98.3      97.7  ...
# 1424     92.7       96.0       97.9       99.4      99.7      98.9  ...
# 1432     91.2       93.6       95.9       97.2      97.8      97.1  ...
#
#       4-Jul-20  11-Jul-20  18-Jul-20  25-Jul-20  1-Aug-20  8-Aug-20  \
# 960       95.3       95.3       94.9       94.5      94.3      93.6
# 961       94.8       93.7       91.1       89.3      87.8      82.8
# 962       92.1       92.0       91.3       90.5      90.2      89.5
# 963       96.4       96.8       96.6       96.2      96.0      95.7
# 964       96.9       97.3       97.4       97.2      97.2      96.8
# ...        ...        ...        ...        ...       ...       ...
# 1400      84.3       85.3       84.6       83.9      82.6      80.2
# 1408      78.7       82.0       80.3       78.8      78.0      75.3
# 1416      96.4       95.3       93.9       92.7      92.5      91.4
# 1424      98.0       97.3       96.4       95.7      95.6      94.5
# 1432      95.3       93.8       92.0       90.6      90.3      89.3
#
#       15-Aug-20  22-Aug-20  29-Aug-20  5-Sep-20
# 960        93.0       92.4       91.9      91.7
# 961        80.2       79.7       78.8      79.5
# 962        88.7       88.0       87.6      87.4
# 963        95.3       94.7       94.3      94.1
# 964        96.5       95.9       95.5      95.3
# ...         ...        ...        ...       ...
# 1400       81.4       80.6       80.8      80.3
# 1408       75.9       74.5       74.5      73.6
# 1416       90.7       88.8       87.9      87.1
# 1424       93.8       92.4       91.5      90.9
# 1432       88.7       86.5       85.7      84.8
#
# [81 rows x 40 columns]

# %%
# Extracting data for all industries in Australia from original dataframe
vic_australia_all_industries = vic_australia_df.loc[vic_australia_df["Industry division"] == "All Industries"]
vic_australia_all_industries
# Out:
#     State or Territory Industry division      Sex    Age group 4-Jan-20  \
# 960                VIC    All Industries    Other     All ages     92.2
# 961                VIC    All Industries    Other     Under 20     83.5
# 962                VIC    All Industries    Other        20-29     90.8
# 963                VIC    All Industries    Other        30-39     93.2
# 964                VIC    All Industries    Other        40-49     93.2
# 965                VIC    All Industries    Other        50-59     93.6
# 966                VIC    All Industries    Other        60-69     94.2
# 967                VIC    All Industries    Other  70 and over     91.7
# 968                VIC    All Industries    Males     All ages     92.3
# 969                VIC    All Industries    Males     Under 20     85.7
# 970                VIC    All Industries    Males        20-29     90.3
# 971                VIC    All Industries    Males        30-39     93.3
# 972                VIC    All Industries    Males        40-49     93.7
# 973                VIC    All Industries    Males        50-59     93.3
# 974                VIC    All Industries    Males        60-69     93.4
# 975                VIC    All Industries    Males  70 and over     90.8
# 976                VIC    All Industries  Females     All ages     93.2
# 977                VIC    All Industries  Females     Under 20     88.2
# 978                VIC    All Industries  Females        20-29     92.7
# 979                VIC    All Industries  Females        30-39     93.9
# 980                VIC    All Industries  Females        40-49       93
# 981                VIC    All Industries  Females        50-59       94
# 982                VIC    All Industries  Females        60-69     95.1
# 983                VIC    All Industries  Females  70 and over       93
#
#      11-Jan-20  18-Jan-20  25-Jan-20  1-Feb-20  8-Feb-20  ...  4-Jul-20  \
# 960       94.3       96.2       97.3      97.9      98.7  ...      95.3
# 961       85.6       89.0       91.9      94.9      96.9  ...      94.8
# 962       93.1       95.5       96.8      97.3      98.2  ...      92.1
# 963       95.3       97.0       97.8      98.1      98.7  ...      96.4
# 964       94.9       96.4       97.4      98.0      98.7  ...      96.9
# 965       95.5       97.0       98.1      98.7      99.1  ...      96.8
# 966       95.7       97.1       98.2      98.8      99.3  ...      94.6
# 967       92.6       94.5       96.0      97.5      98.7  ...      90.0
# 968       95.0       97.2       98.2      98.6      99.1  ...      95.1
# 969       88.0       91.7       94.1      96.7      98.7  ...      94.5
# 970       93.3       96.2       97.3      97.6      98.5  ...      92.3
# 971       95.9       98.1       98.8      98.9      99.2  ...      95.8
# 972       96.0       97.8       98.6      98.9      99.1  ...      96.5
# 973       95.7       97.6       98.6      98.9      99.1  ...      96.2
# 974       95.5       97.4       98.4      98.9      99.4  ...      94.1
# 975       92.1       94.4       95.9      97.3      98.7  ...      90.5
# 976       94.5       95.9       97.1      97.9      98.7  ...      95.5
# 977       89.5       92.3       94.8      97.7      99.3  ...      90.1
# 978       94.2       96.1       97.4      97.9      98.7  ...      92.2
# 979       95.1       96.4       97.2      97.7      98.4  ...      96.9
# 980       94.1       95.2       96.3      97.3      98.4  ...      97.3
# 981       95.4       96.6       97.7      98.6      99.1  ...      97.3
# 982       95.8       96.8       98.0      98.8      99.2  ...      95.0
# 983       93.3       94.6       96.0      97.5      98.5  ...      89.3
#
#      11-Jul-20  18-Jul-20  25-Jul-20  1-Aug-20  8-Aug-20  15-Aug-20  \
# 960       95.3       94.9       94.5      94.3      93.6       93.0
# 961       93.7       91.1       89.3      87.8      82.8       80.2
# 962       92.0       91.3       90.5      90.2      89.5       88.7
# 963       96.8       96.6       96.2      96.0      95.7       95.3
# 964       97.3       97.4       97.2      97.2      96.8       96.5
# 965       97.2       97.2       97.2      97.3      97.0       96.6
# 966       94.0       94.1       94.0      94.1      93.7       93.2
# 967       88.2       88.1       87.7      87.7      86.6       86.0
# 968       95.6       95.3       94.8      94.6      93.9       93.4
# 969       93.2       91.2       89.7      88.3      84.0       81.7
# 970       92.5       91.7       90.9      90.6      89.9       89.2
# 971       96.7       96.5       96.1      95.8      95.4       95.1
# 972       97.6       97.7       97.4      97.2      96.8       96.5
# 973       97.4       97.6       97.2      97.2      96.9       96.5
# 974       94.4       94.7       94.3      94.4      93.9       93.5
# 975       89.1       89.4       88.7      88.8      87.4       87.1
# 976       95.0       94.7       94.3      94.2      93.6       93.0
# 977       89.1       86.0       84.1      82.4      77.9       75.5
# 978       92.0       91.5       90.6      90.3      89.5       88.7
# 979       96.9       96.7       96.2      96.1      95.8       95.4
# 980       97.1       97.1       97.1      97.2      96.9       96.4
# 981       96.9       96.9       97.1      97.4      97.2       96.7
# 982       93.6       93.5       93.7      93.8      93.5       92.8
# 983       86.9       86.2       86.2      86.2      85.2       84.4
#
#      22-Aug-20  29-Aug-20  5-Sep-20
# 960       92.4       91.9      91.7
# 961       79.7       78.8      79.5
# 962       88.0       87.6      87.4
# 963       94.7       94.3      94.1
# 964       95.9       95.5      95.3
# 965       96.0       95.5      95.5
# 966       92.3       91.8      91.8
# 967       84.9       84.3      83.9
# 968       92.9       92.5      92.2
# 969       81.3       80.8      81.5
# 970       88.7       88.2      88.1
# 971       94.6       94.2      94.0
# 972       96.2       95.9      95.6
# 973       96.1       95.8      95.6
# 974       92.9       92.5      92.3
# 975       86.2       85.6      85.5
# 976       92.1       91.6      91.4
# 977       74.9       73.7      73.9
# 978       88.0       87.5      87.2
# 979       94.7       94.3      94.1
# 980       95.7       95.2      95.1
# 981       95.8       95.3      95.3
# 982       91.7       91.1      91.2
# 983       83.1       82.5      81.9
#
# [24 rows x 40 columns]

# %%
# Combining industry division, gender and age group into a single group column
vic_australia_df["Group"] = vic_australia_df["Industry division"] + "_" + vic_australia_df["Sex"] + "_" + vic_australia_df["Age group"]
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Replacing the age group with combined groups
vic_australia_df["Age group"] = vic_australia_df["Group"]
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Removing individual unwanted columns
del vic_australia_df["State or Territory"]

# %%
# Removing individual unwanted columns
del vic_australia_df["Industry division"]

# %%
# Removing individual unwanted columns
del vic_australia_df["Sex"]

# %%
# Removing individual unwanted columns
del vic_australia_df["Group"]

# %%
# Renaming combined column into groups
vic_australia_df = vic_australia_df.rename(columns={
    "Age group":"Group"
})

# %%
# Checking transposed data
vic_australia_df.T.head()
# Out:
#                                     960                            961   \
# Group      All Industries_Other_All ages  All Industries_Other_Under 20
# 4-Jan-20                            92.2                           83.5
# 11-Jan-20                           94.3                           85.6
# 18-Jan-20                           96.2                             89
# 25-Jan-20                           97.3                           91.9
#
#                                  962                         963   \
# Group      All Industries_Other_20-29  All Industries_Other_30-39
# 4-Jan-20                         90.8                        93.2
# 11-Jan-20                        93.1                        95.3
# 18-Jan-20                        95.5                          97
# 25-Jan-20                        96.8                        97.8
#
#                                  964                         965   \
# Group      All Industries_Other_40-49  All Industries_Other_50-59
# 4-Jan-20                         93.2                        93.6
# 11-Jan-20                        94.9                        95.5
# 18-Jan-20                        96.4                          97
# 25-Jan-20                        97.4                        98.1
#
#                                  966                               967   \
# Group      All Industries_Other_60-69  All Industries_Other_70 and over
# 4-Jan-20                         94.2                              91.7
# 11-Jan-20                        95.7                              92.6
# 18-Jan-20                        97.1                              94.5
# 25-Jan-20                        98.2                                96
#
#                                     968                            969   ...  \
# Group      All Industries_Males_All ages  All Industries_Males_Under 20  ...
# 4-Jan-20                            92.3                           85.7  ...
# 11-Jan-20                             95                             88  ...
# 18-Jan-20                           97.2                           91.7  ...
# 25-Jan-20                           98.2                           94.1  ...
#
#                                             1360  \
# Group      Education & training_Females_All ages
# 4-Jan-20                                    85.2
# 11-Jan-20                                   83.2
# 18-Jan-20                                   83.5
# 25-Jan-20                                   85.3
#
#                                                      1368  \
# Group      Health care & social assistance_Other_All ages
# 4-Jan-20                                             94.6
# 11-Jan-20                                            96.3
# 18-Jan-20                                            97.1
# 25-Jan-20                                            98.9
#
#                                                      1376  \
# Group      Health care & social assistance_Males_All ages
# 4-Jan-20                                             95.9
# 11-Jan-20                                            97.2
# 18-Jan-20                                            97.8
# 25-Jan-20                                            99.4
#
#                                                        1384  \
# Group      Health care & social assistance_Females_All ages
# 4-Jan-20                                               94.6
# 11-Jan-20                                              96.3
# 18-Jan-20                                              97.2
# 25-Jan-20                                              99.1
#
#                                                 1392  \
# Group      Arts & recreation services_Other_All ages
# 4-Jan-20                                        91.9
# 11-Jan-20                                       94.4
# 18-Jan-20                                       97.8
# 25-Jan-20                                       99.7
#
#                                                 1400  \
# Group      Arts & recreation services_Males_All ages
# 4-Jan-20                                        95.5
# 11-Jan-20                                       97.4
# 18-Jan-20                                       99.7
# 25-Jan-20                                      100.8
#
#                                                   1408  \
# Group      Arts & recreation services_Females_All ages
# 4-Jan-20                                          89.7
# 11-Jan-20                                         92.8
# 18-Jan-20                                         97.1
# 25-Jan-20                                         99.4
#
#                                     1416                           1424  \
# Group      Other services_Other_All ages  Other services_Males_All ages
# 4-Jan-20                            91.3                           92.7
# 11-Jan-20                           94.2                             96
# 18-Jan-20                           96.3                           97.9
# 25-Jan-20                           97.8                           99.4
#
#                                       1432
# Group      Other services_Females_All ages
# 4-Jan-20                              91.2
# 11-Jan-20                             93.6
# 18-Jan-20                             95.9
# 25-Jan-20                             97.2
#
# [5 rows x 81 columns]

# %%
# Creating a transposed dataframe of Australia data
vic_australia_df_t = vic_australia_df.T

# %%
# Cleaning transposed dataframe
# Grabing the first row for the header
new_header = vic_australia_df_t.iloc[0]

# Taking the data less the header row
vic_australia_df_t = vic_australia_df_t[1:] 

# Setting the header row as the df header
vic_australia_df_t.columns = new_header

# %%
# Filtering data by elements, replace a and b with desired elements
# add & australia_df_t.columns.str.contains(c) for additional filtering
a = "All Industries"
b = "All ages"
filter_df = vic_australia_df_t.loc[:, (vic_australia_df_t.columns.str.contains(a) & vic_australia_df_t.columns.str.contains(b))]
filter_df["All Industries_Other_All ages"] = pd.to_numeric(filter_df["All Industries_Other_All ages"])
filter_df.dtypes
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Group
# All Industries_Other_All ages      float64
# All Industries_Males_All ages       object
# All Industries_Females_All ages     object
# dtype: object

# %%
filter_df["All Industries_Other_All ages"] = pd.to_numeric(filter_df["All Industries_Other_All ages"])
filter_df["All Industries_Males_All ages"] = pd.to_numeric(filter_df["All Industries_Males_All ages"])
filter_df["All Industries_Females_All ages"] = pd.to_numeric(filter_df["All Industries_Females_All ages"])
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
x_axis = np.arange(len(filter_df["All Industries_Other_All ages"]))
x_axis
plt.figure(figsize=((10,10)))
plt.plot(x_axis, filter_df["All Industries_Other_All ages"], marker='o', markerfacecolor='blue', markersize=12, color='yellow', linewidth=4,label="Persons")

x_labels = ("4-Jan-20","11-Jan-20","18-Jan-20","25-Jan-20","1-Feb-20","8-Feb-20","15-Feb-20","22-Feb-20","29-Feb-20","7-Mar-20","14-Mar-20","21-Mar-20",
            "28-Mar-20","4-Apr-20","11-Apr-20","18-Apr-20","25-Apr-20","2-May-20","9-May-20","16-May-20","23-May-20","30-May-20","6-Jun-20",
            "13-Jun-20","20-Jun-20","27-Jun-20","4-Jul-20","11-Jul-20","18-Jul-20","25-Jul-20","1-Aug-20","8-Aug-20","15-Aug-20","22-Aug-20",
            "29-Aug-20","5-Sep-20")
plt.xticks(x_axis,x_labels,rotation=90)
plt.xlabel("Time")
plt.ylabel("Single Touch Payroll Index")
plt.title("Single Touch Payroll Indices across All Industries (QLD)")
plt.legend()
plt.show()

# %%
a = "Accommodation & food services"
b = "Other"
c = "All ages"
filter_df = vic_australia_df_t.loc[:, (vic_australia_df_t.columns.str.contains(a) & vic_australia_df_t.columns.str.contains(b) & vic_australia_df_t.columns.str.contains(c))]
filter_df["Accommodation & food services_Other_All ages"] = pd.to_numeric(filter_df["Accommodation & food services_Other_All ages"])
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
newcol = [a for a in list(filter_df["Accommodation & food services_Other_All ages"][:-1])]
newcol.insert(0,0)
filter_df["last_val"] = newcol
filter_df["diff"] = (filter_df["Accommodation & food services_Other_All ages"] - filter_df["last_val"])/(filter_df_3["last_val"]) * 100
filter_df = filter_df.drop(["4-Jan-20","11-Jan-20","18-Jan-20","25-Jan-20","1-Feb-20","8-Feb-20","15-Feb-20","22-Feb-20","29-Feb-20","7-Mar-20"])
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
# Extracting data for Australia only from original dataframe
wa_australia_df = data.loc[data['State or Territory'] == "WA"]
wa_australia_df
# Out:
#      State or Territory           Industry division      Sex Age group  \
# 2400                 WA              All Industries    Other  All ages
# 2401                 WA              All Industries    Other  Under 20
# 2402                 WA              All Industries    Other     20-29
# 2403                 WA              All Industries    Other     30-39
# 2404                 WA              All Industries    Other     40-49
# ...                 ...                         ...      ...       ...
# 2840                 WA  Arts & recreation services    Males  All ages
# 2848                 WA  Arts & recreation services  Females  All ages
# 2856                 WA              Other services    Other  All ages
# 2864                 WA              Other services    Males  All ages
# 2872                 WA              Other services  Females  All ages
#
#      4-Jan-20  11-Jan-20  18-Jan-20  25-Jan-20  1-Feb-20  8-Feb-20  ...  \
# 2400     94.2       96.6       97.7       98.0      98.0      99.0  ...
# 2401       87       89.6       92.3       94.0      95.2      97.9  ...
# 2402     92.6       95.4       97.1       97.6      97.9      99.0  ...
# 2403     94.3       96.7       97.7       98.0      98.0      98.7  ...
# 2404     95.1       97.2       98.0       98.0      98.0      98.8  ...
# ...       ...        ...        ...        ...       ...       ...  ...
# 2840    100.8      101.7      102.6      103.6     107.1     108.7  ...
# 2848     98.7      100.4      102.0      103.2     109.0     112.4  ...
# 2856     91.6       95.2       96.5       97.0      97.5      98.2  ...
# 2864     93.3       97.3       99.2       99.4      99.3      98.9  ...
# 2872     91.2       94.4       95.0       95.7      96.6      98.1  ...
#
#       4-Jul-20  11-Jul-20  18-Jul-20  25-Jul-20  1-Aug-20  8-Aug-20  \
# 2400      97.9       98.4       98.1       98.3      98.7      98.7
# 2401     100.4      102.2      103.0      104.6     105.8     105.5
# 2402      96.1       97.0       96.9       97.0      97.6      97.8
# 2403      98.1       98.8       98.5       98.6      99.0      99.1
# 2404      98.7       99.2       98.8       99.1      99.6      99.6
# ...        ...        ...        ...        ...       ...       ...
# 2840      91.4       94.5       98.1       99.5     100.1     100.4
# 2848      89.1       92.5       96.7       99.1     100.2     100.1
# 2856      98.8       98.9       99.0       99.2      99.6      99.2
# 2864     100.9      101.5      101.5      101.1     101.2     100.9
# 2872      96.9       96.5       96.7       97.4      97.9      97.4
#
#       15-Aug-20  22-Aug-20  29-Aug-20  5-Sep-20
# 2400       98.9       98.9       99.1      99.1
# 2401      106.9      107.2      107.6     108.2
# 2402       98.1       98.2       98.4      98.4
# 2403       99.3       99.3       99.4      99.4
# 2404       99.8       99.9      100.0     100.1
# ...         ...        ...        ...       ...
# 2840      100.9      100.5       99.9     102.3
# 2848      100.6      100.5       99.7     100.4
# 2856       99.2       98.1       98.1      98.4
# 2864      100.5       99.8       99.4      99.5
# 2872       97.6       96.2       96.4      97.0
#
# [81 rows x 40 columns]

# %%
# Extracting data for all industries in Australia from original dataframe
wa_australia_all_industries = wa_australia_df.loc[wa_australia_df["Industry division"] == "All Industries"]
wa_australia_all_industries
# Out:
#      State or Territory Industry division      Sex    Age group 4-Jan-20  \
# 2400                 WA    All Industries    Other     All ages     94.2
# 2401                 WA    All Industries    Other     Under 20       87
# 2402                 WA    All Industries    Other        20-29     92.6
# 2403                 WA    All Industries    Other        30-39     94.3
# 2404                 WA    All Industries    Other        40-49     95.1
# 2405                 WA    All Industries    Other        50-59     96.2
# 2406                 WA    All Industries    Other        60-69     96.8
# 2407                 WA    All Industries    Other  70 and over     93.5
# 2408                 WA    All Industries    Males     All ages     93.7
# 2409                 WA    All Industries    Males     Under 20     88.4
# 2410                 WA    All Industries    Males        20-29     91.8
# 2411                 WA    All Industries    Males        30-39       94
# 2412                 WA    All Industries    Males        40-49     94.7
# 2413                 WA    All Industries    Males        50-59     94.9
# 2414                 WA    All Industries    Males        60-69       95
# 2415                 WA    All Industries    Males  70 and over     92.7
# 2416                 WA    All Industries  Females     All ages     95.7
# 2417                 WA    All Industries  Females     Under 20       92
# 2418                 WA    All Industries  Females        20-29     94.6
# 2419                 WA    All Industries  Females        30-39     95.3
# 2420                 WA    All Industries  Females        40-49     95.8
# 2421                 WA    All Industries  Females        50-59     97.6
# 2422                 WA    All Industries  Females        60-69     98.7
# 2423                 WA    All Industries  Females  70 and over     94.3
#
#       11-Jan-20  18-Jan-20  25-Jan-20  1-Feb-20  8-Feb-20  ...  4-Jul-20  \
# 2400       96.6       97.7       98.0      98.0      99.0  ...      97.9
# 2401       89.6       92.3       94.0      95.2      97.9  ...     100.4
# 2402       95.4       97.1       97.6      97.9      99.0  ...      96.1
# 2403       96.7       97.7       98.0      98.0      98.7  ...      98.1
# 2404       97.2       98.0       98.0      98.0      98.8  ...      98.7
# 2405       98.4       99.2       99.2      98.8      99.5  ...      98.7
# 2406       98.8       99.3       99.4      98.7      99.7  ...      97.4
# 2407       95.1       93.9       94.5      94.1      97.9  ...      94.2
# 2408       96.6       97.8       98.2      98.1      98.8  ...      96.4
# 2409       92.4       95.0       96.0      97.1      99.1  ...      98.4
# 2410       95.4       97.4       97.8      98.0      98.9  ...      95.3
# 2411       96.7       97.9       98.2      98.2      98.5  ...      96.3
# 2412       97.1       98.1       98.3      98.3      98.8  ...      96.9
# 2413       97.5       98.4       98.7      98.6      98.9  ...      97.1
# 2414       97.5       98.1       98.6      98.1      98.9  ...      96.0
# 2415       94.6       93.1       93.8      93.3      97.3  ...      93.0
# 2416       97.6       98.4       98.5      98.3      99.6  ...      99.1
# 2417       93.0       95.2       96.7      97.3     100.3  ...      97.3
# 2418       96.5       97.8       98.5      98.7      99.9  ...      96.9
# 2419       97.4       98.1       98.2      98.2      99.2  ...      99.9
# 2420       97.6       98.1       97.9      97.7      98.9  ...     100.6
# 2421       99.5      100.1       99.8      99.2     100.1  ...     100.4
# 2422      100.2      100.5      100.3      99.3     100.4  ...      98.8
# 2423       95.6       95.0       95.5      95.2      98.7  ...      95.5
#
#       11-Jul-20  18-Jul-20  25-Jul-20  1-Aug-20  8-Aug-20  15-Aug-20  \
# 2400       98.4       98.1       98.3      98.7      98.7       98.9
# 2401      102.2      103.0      104.6     105.8     105.5      106.9
# 2402       97.0       96.9       97.0      97.6      97.8       98.1
# 2403       98.8       98.5       98.6      99.0      99.1       99.3
# 2404       99.2       98.8       99.1      99.6      99.6       99.8
# 2405       99.3       99.0       99.0      99.3      99.2       99.3
# 2406       97.4       96.5       96.3      96.4      96.2       96.3
# 2407       92.9       91.2       91.1      91.2      91.5       91.8
# 2408       97.6       97.5       97.6      97.6      97.6       97.7
# 2409       99.6       99.8      100.7     101.3     100.8      101.6
# 2410       96.6       96.4       96.5      96.8      97.2       97.2
# 2411       97.7       97.7       97.7      97.8      97.8       98.0
# 2412       98.3       98.4       98.6      98.6      98.5       98.7
# 2413       98.5       98.6       98.6      98.6      98.5       98.6
# 2414       96.8       96.3       96.3      96.1      95.9       95.9
# 2415       92.4       91.2       91.1      90.8      91.5       91.9
# 2416       98.9       98.3       98.5      99.2      99.1       99.4
# 2417       98.8       99.1      100.1     101.3     100.8      101.9
# 2418       97.4       97.4       97.4      98.0      98.1       98.5
# 2419       99.8       99.0       99.3     100.1     100.2      100.4
# 2420      100.1       99.2       99.6     100.5     100.6      100.8
# 2421      100.1       99.3       99.3      99.9      99.8       99.9
# 2422       98.0       96.7       96.3      96.8      96.5       96.6
# 2423       93.5       91.0       90.8      91.4      91.3       91.4
#
#       22-Aug-20  29-Aug-20  5-Sep-20
# 2400       98.9       99.1      99.1
# 2401      107.2      107.6     108.2
# 2402       98.2       98.4      98.4
# 2403       99.3       99.4      99.4
# 2404       99.9      100.0     100.1
# 2405       99.3       99.5      99.7
# 2406       96.2       96.6      96.7
# 2407       92.1       92.3      91.3
# 2408       97.8       97.7      97.7
# 2409      101.6      101.4     102.1
# 2410       97.4       97.4      97.6
# 2411       98.0       97.9      97.9
# 2412       98.8       98.7      98.7
# 2413       98.6       98.6      98.7
# 2414       95.8       96.1      96.0
# 2415       92.4       92.5      91.4
# 2416       99.4       99.7      99.7
# 2417      101.6      101.9     101.8
# 2418       98.5       99.0      98.7
# 2419      100.5      100.6     100.6
# 2420      101.0      101.3     101.4
# 2421      100.0      100.4     100.7
# 2422       96.5       97.1      97.4
# 2423       91.5       91.8      91.1
#
# [24 rows x 40 columns]

# %%
# Combining industry division, gender and age group into a single group column
wa_australia_df["Group"] = wa_australia_df["Industry division"] + "_" + wa_australia_df["Sex"] + "_" + wa_australia_df["Age group"]
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Replacing the age group with combined groups
wa_australia_df["Age group"] = wa_australia_df["Group"]
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Removing individual unwanted columns
del wa_australia_df["State or Territory"]

# %%
# Removing individual unwanted columns
del wa_australia_df["Industry division"]

# %%
# Removing individual unwanted columns
del wa_australia_df["Sex"]

# %%
# Removing individual unwanted columns
del wa_australia_df["Group"]

# %%
# Renaming combined column into groups
wa_australia_df = wa_australia_df.rename(columns={
    "Age group":"Group"
})

# %%
wa_australia_df
# Out:
#                                             Group 4-Jan-20  11-Jan-20  \
# 2400                All Industries_Other_All ages     94.2       96.6
# 2401                All Industries_Other_Under 20       87       89.6
# 2402                   All Industries_Other_20-29     92.6       95.4
# 2403                   All Industries_Other_30-39     94.3       96.7
# 2404                   All Industries_Other_40-49     95.1       97.2
# ...                                           ...      ...        ...
# 2840    Arts & recreation services_Males_All ages    100.8      101.7
# 2848  Arts & recreation services_Females_All ages     98.7      100.4
# 2856                Other services_Other_All ages     91.6       95.2
# 2864                Other services_Males_All ages     93.3       97.3
# 2872              Other services_Females_All ages     91.2       94.4
#
#       18-Jan-20  25-Jan-20  1-Feb-20  8-Feb-20  15-Feb-20  22-Feb-20  \
# 2400       97.7       98.0      98.0      99.0       99.7       99.4
# 2401       92.3       94.0      95.2      97.9       99.1       97.2
# 2402       97.1       97.6      97.9      99.0       99.7       99.7
# 2403       97.7       98.0      98.0      98.7       99.3       99.1
# 2404       98.0       98.0      98.0      98.8       99.3       99.1
# ...         ...        ...       ...       ...        ...        ...
# 2840      102.6      103.6     107.1     108.7      108.6      109.8
# 2848      102.0      103.2     109.0     112.4      112.4      113.8
# 2856       96.5       97.0      97.5      98.2       98.4       99.2
# 2864       99.2       99.4      99.3      98.9       99.0       99.9
# 2872       95.0       95.7      96.6      98.1       98.3       98.9
#
#       29-Feb-20  ...  4-Jul-20  11-Jul-20  18-Jul-20  25-Jul-20  1-Aug-20  \
# 2400       99.1  ...      97.9       98.4       98.1       98.3      98.7
# 2401       96.3  ...     100.4      102.2      103.0      104.6     105.8
# 2402       99.3  ...      96.1       97.0       96.9       97.0      97.6
# 2403       99.1  ...      98.1       98.8       98.5       98.6      99.0
# 2404       99.0  ...      98.7       99.2       98.8       99.1      99.6
# ...         ...  ...       ...        ...        ...        ...       ...
# 2840      103.0  ...      91.4       94.5       98.1       99.5     100.1
# 2848      103.9  ...      89.1       92.5       96.7       99.1     100.2
# 2856       99.4  ...      98.8       98.9       99.0       99.2      99.6
# 2864       99.7  ...     100.9      101.5      101.5      101.1     101.2
# 2872       99.3  ...      96.9       96.5       96.7       97.4      97.9
#
#       8-Aug-20  15-Aug-20  22-Aug-20  29-Aug-20  5-Sep-20
# 2400      98.7       98.9       98.9       99.1      99.1
# 2401     105.5      106.9      107.2      107.6     108.2
# 2402      97.8       98.1       98.2       98.4      98.4
# 2403      99.1       99.3       99.3       99.4      99.4
# 2404      99.6       99.8       99.9      100.0     100.1
# ...        ...        ...        ...        ...       ...
# 2840     100.4      100.9      100.5       99.9     102.3
# 2848     100.1      100.6      100.5       99.7     100.4
# 2856      99.2       99.2       98.1       98.1      98.4
# 2864     100.9      100.5       99.8       99.4      99.5
# 2872      97.4       97.6       96.2       96.4      97.0
#
# [81 rows x 37 columns]

# %%
# Checking transposed data
wa_australia_df.T.head()
# Out:
#                                     2400                           2401  \
# Group      All Industries_Other_All ages  All Industries_Other_Under 20
# 4-Jan-20                            94.2                             87
# 11-Jan-20                           96.6                           89.6
# 18-Jan-20                           97.7                           92.3
# 25-Jan-20                             98                             94
#
#                                  2402                        2403  \
# Group      All Industries_Other_20-29  All Industries_Other_30-39
# 4-Jan-20                         92.6                        94.3
# 11-Jan-20                        95.4                        96.7
# 18-Jan-20                        97.1                        97.7
# 25-Jan-20                        97.6                          98
#
#                                  2404                        2405  \
# Group      All Industries_Other_40-49  All Industries_Other_50-59
# 4-Jan-20                         95.1                        96.2
# 11-Jan-20                        97.2                        98.4
# 18-Jan-20                          98                        99.2
# 25-Jan-20                          98                        99.2
#
#                                  2406                              2407  \
# Group      All Industries_Other_60-69  All Industries_Other_70 and over
# 4-Jan-20                         96.8                              93.5
# 11-Jan-20                        98.8                              95.1
# 18-Jan-20                        99.3                              93.9
# 25-Jan-20                        99.4                              94.5
#
#                                     2408                           2409  ...  \
# Group      All Industries_Males_All ages  All Industries_Males_Under 20  ...
# 4-Jan-20                            93.7                           88.4  ...
# 11-Jan-20                           96.6                           92.4  ...
# 18-Jan-20                           97.8                             95  ...
# 25-Jan-20                           98.2                             96  ...
#
#                                             2800  \
# Group      Education & training_Females_All ages
# 4-Jan-20                                    94.1
# 11-Jan-20                                   94.1
# 18-Jan-20                                   93.8
# 25-Jan-20                                   90.6
#
#                                                      2808  \
# Group      Health care & social assistance_Other_All ages
# 4-Jan-20                                             97.4
# 11-Jan-20                                           100.8
# 18-Jan-20                                           101.5
# 25-Jan-20                                           102.4
#
#                                                      2816  \
# Group      Health care & social assistance_Males_All ages
# 4-Jan-20                                             96.8
# 11-Jan-20                                           100.3
# 18-Jan-20                                           100.7
# 25-Jan-20                                           101.4
#
#                                                        2824  \
# Group      Health care & social assistance_Females_All ages
# 4-Jan-20                                                 98
# 11-Jan-20                                             101.2
# 18-Jan-20                                               102
# 25-Jan-20                                             102.9
#
#                                                 2832  \
# Group      Arts & recreation services_Other_All ages
# 4-Jan-20                                        99.2
# 11-Jan-20                                      100.6
# 18-Jan-20                                        102
# 25-Jan-20                                      103.1
#
#                                                 2840  \
# Group      Arts & recreation services_Males_All ages
# 4-Jan-20                                       100.8
# 11-Jan-20                                      101.7
# 18-Jan-20                                      102.6
# 25-Jan-20                                      103.6
#
#                                                   2848  \
# Group      Arts & recreation services_Females_All ages
# 4-Jan-20                                          98.7
# 11-Jan-20                                        100.4
# 18-Jan-20                                          102
# 25-Jan-20                                        103.2
#
#                                     2856                           2864  \
# Group      Other services_Other_All ages  Other services_Males_All ages
# 4-Jan-20                            91.6                           93.3
# 11-Jan-20                           95.2                           97.3
# 18-Jan-20                           96.5                           99.2
# 25-Jan-20                             97                           99.4
#
#                                       2872
# Group      Other services_Females_All ages
# 4-Jan-20                              91.2
# 11-Jan-20                             94.4
# 18-Jan-20                               95
# 25-Jan-20                             95.7
#
# [5 rows x 81 columns]

# %%
# Creating a transposed dataframe of Australia data
wa_australia_df_t = wa_australia_df.T

# %%
# Cleaning transposed dataframe
# Grabing the first row for the header
new_header = wa_australia_df_t.iloc[0]

# Taking the data less the header row
wa_australia_df_t = wa_australia_df_t[1:] 

# Setting the header row as the df header
wa_australia_df_t.columns = new_header

# %%
wa_australia_df_t.head()
# Out:
# Group     All Industries_Other_All ages All Industries_Other_Under 20  \
# 4-Jan-20                           94.2                            87
# 11-Jan-20                          96.6                          89.6
# 18-Jan-20                          97.7                          92.3
# 25-Jan-20                            98                            94
# 1-Feb-20                             98                          95.2
#
# Group     All Industries_Other_20-29 All Industries_Other_30-39  \
# 4-Jan-20                        92.6                       94.3
# 11-Jan-20                       95.4                       96.7
# 18-Jan-20                       97.1                       97.7
# 25-Jan-20                       97.6                         98
# 1-Feb-20                        97.9                         98
#
# Group     All Industries_Other_40-49 All Industries_Other_50-59  \
# 4-Jan-20                        95.1                       96.2
# 11-Jan-20                       97.2                       98.4
# 18-Jan-20                         98                       99.2
# 25-Jan-20                         98                       99.2
# 1-Feb-20                          98                       98.8
#
# Group     All Industries_Other_60-69 All Industries_Other_70 and over  \
# 4-Jan-20                        96.8                             93.5
# 11-Jan-20                       98.8                             95.1
# 18-Jan-20                       99.3                             93.9
# 25-Jan-20                       99.4                             94.5
# 1-Feb-20                        98.7                             94.1
#
# Group     All Industries_Males_All ages All Industries_Males_Under 20  ...  \
# 4-Jan-20                           93.7                          88.4  ...
# 11-Jan-20                          96.6                          92.4  ...
# 18-Jan-20                          97.8                            95  ...
# 25-Jan-20                          98.2                            96  ...
# 1-Feb-20                           98.1                          97.1  ...
#
# Group     Education & training_Females_All ages  \
# 4-Jan-20                                   94.1
# 11-Jan-20                                  94.1
# 18-Jan-20                                  93.8
# 25-Jan-20                                  90.6
# 1-Feb-20                                   89.2
#
# Group     Health care & social assistance_Other_All ages  \
# 4-Jan-20                                            97.4
# 11-Jan-20                                          100.8
# 18-Jan-20                                          101.5
# 25-Jan-20                                          102.4
# 1-Feb-20                                             102
#
# Group     Health care & social assistance_Males_All ages  \
# 4-Jan-20                                            96.8
# 11-Jan-20                                          100.3
# 18-Jan-20                                          100.7
# 25-Jan-20                                          101.4
# 1-Feb-20                                           101.2
#
# Group     Health care & social assistance_Females_All ages  \
# 4-Jan-20                                                98
# 11-Jan-20                                            101.2
# 18-Jan-20                                              102
# 25-Jan-20                                            102.9
# 1-Feb-20                                             102.5
#
# Group     Arts & recreation services_Other_All ages  \
# 4-Jan-20                                       99.2
# 11-Jan-20                                     100.6
# 18-Jan-20                                       102
# 25-Jan-20                                     103.1
# 1-Feb-20                                      108.1
#
# Group     Arts & recreation services_Males_All ages  \
# 4-Jan-20                                      100.8
# 11-Jan-20                                     101.7
# 18-Jan-20                                     102.6
# 25-Jan-20                                     103.6
# 1-Feb-20                                      107.1
#
# Group     Arts & recreation services_Females_All ages  \
# 4-Jan-20                                         98.7
# 11-Jan-20                                       100.4
# 18-Jan-20                                         102
# 25-Jan-20                                       103.2
# 1-Feb-20                                          109
#
# Group     Other services_Other_All ages Other services_Males_All ages  \
# 4-Jan-20                           91.6                          93.3
# 11-Jan-20                          95.2                          97.3
# 18-Jan-20                          96.5                          99.2
# 25-Jan-20                            97                          99.4
# 1-Feb-20                           97.5                          99.3
#
# Group     Other services_Females_All ages
# 4-Jan-20                             91.2
# 11-Jan-20                            94.4
# 18-Jan-20                              95
# 25-Jan-20                            95.7
# 1-Feb-20                             96.6
#
# [5 rows x 81 columns]

# %%
# Filtering by elements check
wa_australia_df_t.columns.str.contains("Male") & wa_australia_df_t.columns.str.contains("Female")
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False])

# %%
# Filtering data by elements, replace a and b with desired elements
# add & australia_df_t.columns.str.contains(c) for additional filtering
a = "All Industries"
b = "All ages"
filter_df = wa_australia_df_t.loc[:, (wa_australia_df_t.columns.str.contains(a) & wa_australia_df_t.columns.str.contains(b))]
filter_df["All Industries_Other_All ages"] = pd.to_numeric(filter_df["All Industries_Other_All ages"])
filter_df.dtypes
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Group
# All Industries_Other_All ages      float64
# All Industries_Males_All ages       object
# All Industries_Females_All ages     object
# dtype: object

# %%
filter_df["All Industries_Other_All ages"] = pd.to_numeric(filter_df["All Industries_Other_All ages"])
filter_df["All Industries_Males_All ages"] = pd.to_numeric(filter_df["All Industries_Males_All ages"])
filter_df["All Industries_Females_All ages"] = pd.to_numeric(filter_df["All Industries_Females_All ages"])
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
x_axis = np.arange(len(filter_df["All Industries_Other_All ages"]))
x_axis
plt.figure(figsize=((10,10)))
plt.plot(x_axis, filter_df["All Industries_Other_All ages"], marker='o', markerfacecolor='blue', markersize=12, color='yellow', linewidth=4,label="Persons")

x_labels = ("4-Jan-20","11-Jan-20","18-Jan-20","25-Jan-20","1-Feb-20","8-Feb-20","15-Feb-20","22-Feb-20","29-Feb-20","7-Mar-20","14-Mar-20","21-Mar-20",
            "28-Mar-20","4-Apr-20","11-Apr-20","18-Apr-20","25-Apr-20","2-May-20","9-May-20","16-May-20","23-May-20","30-May-20","6-Jun-20",
            "13-Jun-20","20-Jun-20","27-Jun-20","4-Jul-20","11-Jul-20","18-Jul-20","25-Jul-20","1-Aug-20","8-Aug-20","15-Aug-20","22-Aug-20",
            "29-Aug-20","5-Sep-20")
plt.xticks(x_axis,x_labels,rotation=90)
plt.xlabel("Time")
plt.ylabel("Single Touch Payroll Index")
plt.title("Single Touch Payroll Indices across All Industries (QLD)")
plt.legend()
plt.show()
# Saves an image of our chart so that we can view it in a folder

# %%
a = "All Industries"
b = "Other"
c = "All ages"
filter_df = wa_australia_df_t.loc[:, (wa_australia_df_t.columns.str.contains(a) & wa_australia_df_t.columns.str.contains(b) & wa_australia_df_t.columns.str.contains(c))]
filter_df["All Industries_Other_All ages"] = pd.to_numeric(filter_df["All Industries_Other_All ages"])
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
newcol = [a for a in list(filter_df["All Industries_Other_All ages"][:-1])]
newcol.insert(0,0)
filter_df["last_val"] = newcol
filter_df["diff"] = (filter_df["All Industries_Other_All ages"] - filter_df["last_val"])/(filter_df["last_val"]) * 100
filter_df = filter_df.drop(["4-Jan-20","11-Jan-20","18-Jan-20","25-Jan-20","1-Feb-20","8-Feb-20","15-Feb-20","22-Feb-20","29-Feb-20","7-Mar-20"])
filter_df.to_csv("wa_percent_change_australia.csv", index=False, header=True)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
# Extracting data for Australia only from original dataframe
qld_australia_df = data.loc[data['State or Territory'] == "QLD"]
qld_australia_df
# Out:
#      State or Territory           Industry division      Sex Age group  \
# 1440                QLD              All Industries    Other  All ages
# 1441                QLD              All Industries    Other  Under 20
# 1442                QLD              All Industries    Other     20-29
# 1443                QLD              All Industries    Other     30-39
# 1444                QLD              All Industries    Other     40-49
# ...                 ...                         ...      ...       ...
# 1880                QLD  Arts & recreation services    Males  All ages
# 1888                QLD  Arts & recreation services  Females  All ages
# 1896                QLD              Other services    Other  All ages
# 1904                QLD              Other services    Males  All ages
# 1912                QLD              Other services  Females  All ages
#
#      4-Jan-20  11-Jan-20  18-Jan-20  25-Jan-20  1-Feb-20  8-Feb-20  ...  \
# 1440     92.4       95.6       97.1       97.8      98.1      98.6  ...
# 1441     87.4       91.6       91.6       93.2      93.5      97.7  ...
# 1442     91.4       95.0       97.0       97.7      97.7      98.1  ...
# 1443     93.1       96.1       97.6       98.1      98.3      98.5  ...
# 1444     93.2       95.9       97.4       98.0      98.4      98.6  ...
# ...       ...        ...        ...        ...       ...       ...  ...
# 1880     93.1       96.4       97.9       98.8     100.6     101.0  ...
# 1888     90.4       95.6       98.5       99.7     102.2     103.1  ...
# 1896     90.6       94.5       97.1       98.6      98.9      98.6  ...
# 1904       92       96.2       98.9       99.8      99.6      98.7  ...
# 1912       90       93.7       96.0       97.9      98.6      98.8  ...
#
#       4-Jul-20  11-Jul-20  18-Jul-20  25-Jul-20  1-Aug-20  8-Aug-20  \
# 1440      96.4       96.9       97.1       97.5      97.4      97.1
# 1441      98.9      100.3      101.5      102.3     102.8      98.9
# 1442      94.1       94.8       95.2       95.6      95.5      95.5
# 1443      96.6       97.2       97.4       97.7      97.5      97.5
# 1444      97.4       97.9       98.1       98.5      98.4      98.4
# ...        ...        ...        ...        ...       ...       ...
# 1880      87.3       89.0       90.2       91.3      91.2      91.0
# 1888      85.5       89.1       90.1       91.6      91.4      91.2
# 1896      96.9       96.8       97.2       97.6      96.3      96.2
# 1904      97.4       96.9       97.0       97.0      96.3      96.3
# 1912      96.2       96.4       96.9       97.6      95.6      95.4
#
#       15-Aug-20  22-Aug-20  29-Aug-20  5-Sep-20
# 1440       96.9       97.2       96.5      96.9
# 1441       98.8      100.3      100.5     101.9
# 1442       95.2       95.8       95.3      95.8
# 1443       97.3       97.6       96.9      97.2
# 1444       98.2       98.3       97.6      98.0
# ...         ...        ...        ...       ...
# 1880       91.3       92.7       91.6      91.4
# 1888       91.6       93.0       92.5      91.9
# 1896       96.0       95.9       95.5      96.1
# 1904       96.1       95.8       95.4      95.6
# 1912       95.1       95.1       94.8      95.6
#
# [81 rows x 40 columns]

# %%
# Extracting data for all industries in Australia from original dataframe
qld_australia_all_industries = qld_australia_df.loc[qld_australia_df["Industry division"] == "All Industries"]
qld_australia_all_industries
# Out:
#      State or Territory Industry division      Sex    Age group 4-Jan-20  \
# 1440                QLD    All Industries    Other     All ages     92.4
# 1441                QLD    All Industries    Other     Under 20     87.4
# 1442                QLD    All Industries    Other        20-29     91.4
# 1443                QLD    All Industries    Other        30-39     93.1
# 1444                QLD    All Industries    Other        40-49     93.2
# 1445                QLD    All Industries    Other        50-59     93.7
# 1446                QLD    All Industries    Other        60-69     93.7
# 1447                QLD    All Industries    Other  70 and over     89.7
# 1448                QLD    All Industries    Males     All ages     92.4
# 1449                QLD    All Industries    Males     Under 20     88.7
# 1450                QLD    All Industries    Males        20-29     90.2
# 1451                QLD    All Industries    Males        30-39     93.2
# 1452                QLD    All Industries    Males        40-49     93.7
# 1453                QLD    All Industries    Males        50-59     93.7
# 1454                QLD    All Industries    Males        60-69     93.5
# 1455                QLD    All Industries    Males  70 and over     89.1
# 1456                QLD    All Industries  Females     All ages     93.1
# 1457                QLD    All Industries  Females     Under 20     91.1
# 1458                QLD    All Industries  Females        20-29     93.2
# 1459                QLD    All Industries  Females        30-39     93.6
# 1460                QLD    All Industries  Females        40-49     92.9
# 1461                QLD    All Industries  Females        50-59     93.7
# 1462                QLD    All Industries  Females        60-69       94
# 1463                QLD    All Industries  Females  70 and over     90.5
#
#       11-Jan-20  18-Jan-20  25-Jan-20  1-Feb-20  8-Feb-20  ...  4-Jul-20  \
# 1440       95.6       97.1       97.8      98.1      98.6  ...      96.4
# 1441       91.6       91.6       93.2      93.5      97.7  ...      98.9
# 1442       95.0       97.0       97.7      97.7      98.1  ...      94.1
# 1443       96.1       97.6       98.1      98.3      98.5  ...      96.6
# 1444       95.9       97.4       98.0      98.4      98.6  ...      97.4
# 1445       96.4       97.7       98.2      98.6      98.8  ...      97.5
# 1446       96.5       97.8       98.5      99.0      99.1  ...      95.8
# 1447       92.6       94.2       96.9      97.8      98.7  ...      93.6
# 1448       96.4       98.1       98.6      98.7      99.0  ...      96.2
# 1449       93.4       93.5       94.8      95.0      98.9  ...      98.1
# 1450       95.1       97.3       98.1      98.1      98.5  ...      94.3
# 1451       96.9       98.6       99.0      99.0      99.0  ...      96.1
# 1452       97.0       98.6       98.9      98.9      99.0  ...      97.0
# 1453       96.9       98.5       98.8      98.9      99.1  ...      97.2
# 1454       96.9       98.5       99.1      99.5      99.5  ...      95.8
# 1455       92.0       94.1       96.5      97.6      98.7  ...      93.9
# 1456       95.5       96.8       97.5      97.9      98.5  ...      96.4
# 1457       94.4       94.4       95.7      95.9      99.4  ...      95.0
# 1458       95.7       97.2       97.9      97.8      98.1  ...      94.1
# 1459       95.8       97.0       97.5      97.9      98.3  ...      97.1
# 1460       95.0       96.3       97.2      97.9      98.3  ...      97.8
# 1461       95.9       97.0       97.8      98.3      98.6  ...      97.9
# 1462       96.1       97.1       98.0      98.5      98.7  ...      95.8
# 1463       93.3       94.4       97.2      98.1      98.7  ...      93.1
#
#       11-Jul-20  18-Jul-20  25-Jul-20  1-Aug-20  8-Aug-20  15-Aug-20  \
# 1440       96.9       97.1       97.5      97.4      97.1       96.9
# 1441      100.3      101.5      102.3     102.8      98.9       98.8
# 1442       94.8       95.2       95.6      95.5      95.5       95.2
# 1443       97.2       97.4       97.7      97.5      97.5       97.3
# 1444       97.9       98.1       98.5      98.4      98.4       98.2
# 1445       97.9       98.0       98.5      98.4      98.4       98.2
# 1446       95.5       95.6       95.8      95.7      95.5       95.1
# 1447       92.4       92.6       92.6      92.7      92.2       91.6
# 1448       96.7       96.7       97.2      97.0      96.8       96.5
# 1449       98.7       98.9       99.4      99.6      96.0       95.3
# 1450       95.1       95.2       95.7      95.4      95.5       95.0
# 1451       96.8       96.8       97.2      97.0      96.9       96.7
# 1452       97.7       97.7       98.2      98.0      97.9       97.7
# 1453       97.9       97.9       98.5      98.5      98.4       98.2
# 1454       95.9       96.0       96.3      96.2      96.1       95.8
# 1455       92.8       93.0       93.2      93.7      93.1       92.5
# 1456       96.7       97.0       97.3      97.2      97.0       96.7
# 1457       96.3       97.3       98.0      98.3      94.7       94.7
# 1458       94.8       95.3       95.6      95.5      95.4       95.2
# 1459       97.5       97.8       98.1      97.9      98.0       97.7
# 1460       98.1       98.5       98.9      98.8      98.8       98.5
# 1461       97.9       98.1       98.4      98.4      98.3       98.2
# 1462       95.1       95.2       95.4      95.2      94.9       94.4
# 1463       91.8       92.0       91.7      91.4      91.0       90.4
#
#       22-Aug-20  29-Aug-20  5-Sep-20
# 1440       97.2       96.5      96.9
# 1441      100.3      100.5     101.9
# 1442       95.8       95.3      95.8
# 1443       97.6       96.9      97.2
# 1444       98.3       97.6      98.0
# 1445       98.3       97.5      97.9
# 1446       95.1       94.2      94.6
# 1447       91.7       90.9      90.9
# 1448       96.8       96.1      96.3
# 1449       96.7       96.3      97.8
# 1450       95.8       95.2      95.7
# 1451       96.9       96.3      96.6
# 1452       97.9       97.2      97.3
# 1453       98.3       97.5      97.8
# 1454       95.8       94.9      95.1
# 1455       92.7       92.0      91.9
# 1456       96.9       96.2      96.7
# 1457       95.8       95.7      96.6
# 1458       95.6       95.2      95.7
# 1459       98.0       97.2      97.7
# 1460       98.7       98.0      98.6
# 1461       98.2       97.4      98.0
# 1462       94.4       93.4      94.1
# 1463       90.4       89.5      89.8
#
# [24 rows x 40 columns]

# %%
# Combining industry division, gender and age group into a single group column
qld_australia_df["Group"] = qld_australia_df["Industry division"] + "_" + qld_australia_df["Sex"] + "_" + qld_australia_df["Age group"]
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Replacing the age group with combined groups
qld_australia_df["Age group"] = qld_australia_df["Group"]
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Removing individual unwanted columns
del qld_australia_df["State or Territory"]

# %%
# Removing individual unwanted columns
del qld_australia_df["Industry division"]

# %%
# Removing individual unwanted columns
del qld_australia_df["Sex"]

# %%
# Removing individual unwanted columns
del qld_australia_df["Group"]

# %%
# Renaming combined column into groups
qld_australia_df = qld_australia_df.rename(columns={
    "Age group":"Group"
})

# %%
qld_australia_df
# Out:
#                                             Group 4-Jan-20  11-Jan-20  \
# 1440                All Industries_Other_All ages     92.4       95.6
# 1441                All Industries_Other_Under 20     87.4       91.6
# 1442                   All Industries_Other_20-29     91.4       95.0
# 1443                   All Industries_Other_30-39     93.1       96.1
# 1444                   All Industries_Other_40-49     93.2       95.9
# ...                                           ...      ...        ...
# 1880    Arts & recreation services_Males_All ages     93.1       96.4
# 1888  Arts & recreation services_Females_All ages     90.4       95.6
# 1896                Other services_Other_All ages     90.6       94.5
# 1904                Other services_Males_All ages       92       96.2
# 1912              Other services_Females_All ages       90       93.7
#
#       18-Jan-20  25-Jan-20  1-Feb-20  8-Feb-20  15-Feb-20  22-Feb-20  \
# 1440       97.1       97.8      98.1      98.6       99.1       99.3
# 1441       91.6       93.2      93.5      97.7       98.4       97.1
# 1442       97.0       97.7      97.7      98.1       98.8       99.2
# 1443       97.6       98.1      98.3      98.5       99.1       99.5
# 1444       97.4       98.0      98.4      98.6       99.2       99.4
# ...         ...        ...       ...       ...        ...        ...
# 1880       97.9       98.8     100.6     101.0      101.6      102.9
# 1888       98.5       99.7     102.2     103.1      103.9      104.0
# 1896       97.1       98.6      98.9      98.6       99.1       99.5
# 1904       98.9       99.8      99.6      98.7       99.0       99.2
# 1912       96.0       97.9      98.6      98.8       99.5      100.0
#
#       29-Feb-20  ...  4-Jul-20  11-Jul-20  18-Jul-20  25-Jul-20  1-Aug-20  \
# 1440       99.1  ...      96.4       96.9       97.1       97.5      97.4
# 1441       96.1  ...      98.9      100.3      101.5      102.3     102.8
# 1442       99.0  ...      94.1       94.8       95.2       95.6      95.5
# 1443       99.3  ...      96.6       97.2       97.4       97.7      97.5
# 1444       99.3  ...      97.4       97.9       98.1       98.5      98.4
# ...         ...  ...       ...        ...        ...        ...       ...
# 1880      102.8  ...      87.3       89.0       90.2       91.3      91.2
# 1888      103.3  ...      85.5       89.1       90.1       91.6      91.4
# 1896       99.9  ...      96.9       96.8       97.2       97.6      96.3
# 1904       99.7  ...      97.4       96.9       97.0       97.0      96.3
# 1912      100.2  ...      96.2       96.4       96.9       97.6      95.6
#
#       8-Aug-20  15-Aug-20  22-Aug-20  29-Aug-20  5-Sep-20
# 1440      97.1       96.9       97.2       96.5      96.9
# 1441      98.9       98.8      100.3      100.5     101.9
# 1442      95.5       95.2       95.8       95.3      95.8
# 1443      97.5       97.3       97.6       96.9      97.2
# 1444      98.4       98.2       98.3       97.6      98.0
# ...        ...        ...        ...        ...       ...
# 1880      91.0       91.3       92.7       91.6      91.4
# 1888      91.2       91.6       93.0       92.5      91.9
# 1896      96.2       96.0       95.9       95.5      96.1
# 1904      96.3       96.1       95.8       95.4      95.6
# 1912      95.4       95.1       95.1       94.8      95.6
#
# [81 rows x 37 columns]

# %%
# Checking transposed data
qld_australia_df.T.head()
# Out:
#                                     1440                           1441  \
# Group      All Industries_Other_All ages  All Industries_Other_Under 20
# 4-Jan-20                            92.4                           87.4
# 11-Jan-20                           95.6                           91.6
# 18-Jan-20                           97.1                           91.6
# 25-Jan-20                           97.8                           93.2
#
#                                  1442                        1443  \
# Group      All Industries_Other_20-29  All Industries_Other_30-39
# 4-Jan-20                         91.4                        93.1
# 11-Jan-20                          95                        96.1
# 18-Jan-20                          97                        97.6
# 25-Jan-20                        97.7                        98.1
#
#                                  1444                        1445  \
# Group      All Industries_Other_40-49  All Industries_Other_50-59
# 4-Jan-20                         93.2                        93.7
# 11-Jan-20                        95.9                        96.4
# 18-Jan-20                        97.4                        97.7
# 25-Jan-20                          98                        98.2
#
#                                  1446                              1447  \
# Group      All Industries_Other_60-69  All Industries_Other_70 and over
# 4-Jan-20                         93.7                              89.7
# 11-Jan-20                        96.5                              92.6
# 18-Jan-20                        97.8                              94.2
# 25-Jan-20                        98.5                              96.9
#
#                                     1448                           1449  ...  \
# Group      All Industries_Males_All ages  All Industries_Males_Under 20  ...
# 4-Jan-20                            92.4                           88.7  ...
# 11-Jan-20                           96.4                           93.4  ...
# 18-Jan-20                           98.1                           93.5  ...
# 25-Jan-20                           98.6                           94.8  ...
#
#                                             1840  \
# Group      Education & training_Females_All ages
# 4-Jan-20                                    79.8
# 11-Jan-20                                   80.5
# 18-Jan-20                                   81.8
# 25-Jan-20                                   84.9
#
#                                                      1848  \
# Group      Health care & social assistance_Other_All ages
# 4-Jan-20                                             94.2
# 11-Jan-20                                            95.7
# 18-Jan-20                                            96.7
# 25-Jan-20                                            97.3
#
#                                                      1856  \
# Group      Health care & social assistance_Males_All ages
# 4-Jan-20                                             95.4
# 11-Jan-20                                            96.6
# 18-Jan-20                                            97.4
# 25-Jan-20                                            98.1
#
#                                                        1864  \
# Group      Health care & social assistance_Females_All ages
# 4-Jan-20                                               94.2
# 11-Jan-20                                              95.8
# 18-Jan-20                                              96.8
# 25-Jan-20                                              97.2
#
#                                                 1872  \
# Group      Arts & recreation services_Other_All ages
# 4-Jan-20                                        91.4
# 11-Jan-20                                       95.7
# 18-Jan-20                                       97.9
# 25-Jan-20                                       99.1
#
#                                                 1880  \
# Group      Arts & recreation services_Males_All ages
# 4-Jan-20                                        93.1
# 11-Jan-20                                       96.4
# 18-Jan-20                                       97.9
# 25-Jan-20                                       98.8
#
#                                                   1888  \
# Group      Arts & recreation services_Females_All ages
# 4-Jan-20                                          90.4
# 11-Jan-20                                         95.6
# 18-Jan-20                                         98.5
# 25-Jan-20                                         99.7
#
#                                     1896                           1904  \
# Group      Other services_Other_All ages  Other services_Males_All ages
# 4-Jan-20                            90.6                             92
# 11-Jan-20                           94.5                           96.2
# 18-Jan-20                           97.1                           98.9
# 25-Jan-20                           98.6                           99.8
#
#                                       1912
# Group      Other services_Females_All ages
# 4-Jan-20                                90
# 11-Jan-20                             93.7
# 18-Jan-20                               96
# 25-Jan-20                             97.9
#
# [5 rows x 81 columns]

# %%
# Creating a transposed dataframe of Australia data
qld_australia_df_t = qld_australia_df.T

# %%
# Cleaning transposed dataframe
# Grabing the first row for the header
new_header = qld_australia_df_t.iloc[0]

# Taking the data less the header row
qld_australia_df_t = qld_australia_df_t[1:] 

# Setting the header row as the df header
qld_australia_df_t.columns = new_header

# %%
qld_australia_df_t.head()
# Out:
# Group     All Industries_Other_All ages All Industries_Other_Under 20  \
# 4-Jan-20                           92.4                          87.4
# 11-Jan-20                          95.6                          91.6
# 18-Jan-20                          97.1                          91.6
# 25-Jan-20                          97.8                          93.2
# 1-Feb-20                           98.1                          93.5
#
# Group     All Industries_Other_20-29 All Industries_Other_30-39  \
# 4-Jan-20                        91.4                       93.1
# 11-Jan-20                         95                       96.1
# 18-Jan-20                         97                       97.6
# 25-Jan-20                       97.7                       98.1
# 1-Feb-20                        97.7                       98.3
#
# Group     All Industries_Other_40-49 All Industries_Other_50-59  \
# 4-Jan-20                        93.2                       93.7
# 11-Jan-20                       95.9                       96.4
# 18-Jan-20                       97.4                       97.7
# 25-Jan-20                         98                       98.2
# 1-Feb-20                        98.4                       98.6
#
# Group     All Industries_Other_60-69 All Industries_Other_70 and over  \
# 4-Jan-20                        93.7                             89.7
# 11-Jan-20                       96.5                             92.6
# 18-Jan-20                       97.8                             94.2
# 25-Jan-20                       98.5                             96.9
# 1-Feb-20                          99                             97.8
#
# Group     All Industries_Males_All ages All Industries_Males_Under 20  ...  \
# 4-Jan-20                           92.4                          88.7  ...
# 11-Jan-20                          96.4                          93.4  ...
# 18-Jan-20                          98.1                          93.5  ...
# 25-Jan-20                          98.6                          94.8  ...
# 1-Feb-20                           98.7                            95  ...
#
# Group     Education & training_Females_All ages  \
# 4-Jan-20                                   79.8
# 11-Jan-20                                  80.5
# 18-Jan-20                                  81.8
# 25-Jan-20                                  84.9
# 1-Feb-20                                   89.3
#
# Group     Health care & social assistance_Other_All ages  \
# 4-Jan-20                                            94.2
# 11-Jan-20                                           95.7
# 18-Jan-20                                           96.7
# 25-Jan-20                                           97.3
# 1-Feb-20                                            97.1
#
# Group     Health care & social assistance_Males_All ages  \
# 4-Jan-20                                            95.4
# 11-Jan-20                                           96.6
# 18-Jan-20                                           97.4
# 25-Jan-20                                           98.1
# 1-Feb-20                                            97.9
#
# Group     Health care & social assistance_Females_All ages  \
# 4-Jan-20                                              94.2
# 11-Jan-20                                             95.8
# 18-Jan-20                                             96.8
# 25-Jan-20                                             97.2
# 1-Feb-20                                              97.1
#
# Group     Arts & recreation services_Other_All ages  \
# 4-Jan-20                                       91.4
# 11-Jan-20                                      95.7
# 18-Jan-20                                      97.9
# 25-Jan-20                                      99.1
# 1-Feb-20                                      101.5
#
# Group     Arts & recreation services_Males_All ages  \
# 4-Jan-20                                       93.1
# 11-Jan-20                                      96.4
# 18-Jan-20                                      97.9
# 25-Jan-20                                      98.8
# 1-Feb-20                                      100.6
#
# Group     Arts & recreation services_Females_All ages  \
# 4-Jan-20                                         90.4
# 11-Jan-20                                        95.6
# 18-Jan-20                                        98.5
# 25-Jan-20                                        99.7
# 1-Feb-20                                        102.2
#
# Group     Other services_Other_All ages Other services_Males_All ages  \
# 4-Jan-20                           90.6                            92
# 11-Jan-20                          94.5                          96.2
# 18-Jan-20                          97.1                          98.9
# 25-Jan-20                          98.6                          99.8
# 1-Feb-20                           98.9                          99.6
#
# Group     Other services_Females_All ages
# 4-Jan-20                               90
# 11-Jan-20                            93.7
# 18-Jan-20                              96
# 25-Jan-20                            97.9
# 1-Feb-20                             98.6
#
# [5 rows x 81 columns]

# %%
# Filtering data by elements, replace a and b with desired elements
# add & australia_df_t.columns.str.contains(c) for additional filtering
a = "All Industries"
b = "All ages"
filter_df = qld_australia_df_t.loc[:, (qld_australia_df_t.columns.str.contains(a) & qld_australia_df_t.columns.str.contains(b))]
filter_df["All Industries_Other_All ages"] = pd.to_numeric(filter_df["All Industries_Other_All ages"])
filter_df.dtypes
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Group
# All Industries_Other_All ages      float64
# All Industries_Males_All ages       object
# All Industries_Females_All ages     object
# dtype: object

# %%
filter_df["All Industries_Other_All ages"] = pd.to_numeric(filter_df["All Industries_Other_All ages"])
filter_df["All Industries_Males_All ages"] = pd.to_numeric(filter_df["All Industries_Males_All ages"])
filter_df["All Industries_Females_All ages"] = pd.to_numeric(filter_df["All Industries_Females_All ages"])
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
x_axis = np.arange(len(filter_df["All Industries_Other_All ages"]))
x_axis
plt.figure(figsize=((10,10)))
plt.plot(x_axis, filter_df["All Industries_Other_All ages"], marker='o', markerfacecolor='blue', markersize=12, color='yellow', linewidth=4,label="Persons")

x_labels = ("4-Jan-20","11-Jan-20","18-Jan-20","25-Jan-20","1-Feb-20","8-Feb-20","15-Feb-20","22-Feb-20","29-Feb-20","7-Mar-20","14-Mar-20","21-Mar-20",
            "28-Mar-20","4-Apr-20","11-Apr-20","18-Apr-20","25-Apr-20","2-May-20","9-May-20","16-May-20","23-May-20","30-May-20","6-Jun-20",
            "13-Jun-20","20-Jun-20","27-Jun-20","4-Jul-20","11-Jul-20","18-Jul-20","25-Jul-20","1-Aug-20","8-Aug-20","15-Aug-20","22-Aug-20",
            "29-Aug-20","5-Sep-20")
plt.xticks(x_axis,x_labels,rotation=90)
plt.xlabel("Time")
plt.ylabel("Single Touch Payroll Index")
plt.title("Single Touch Payroll Indices across All Industries (QLD)")
plt.legend()
plt.show()

# %%
a = "All Industries"
b = "Other"
c = "All ages"
filter_df = qld_australia_df_t.loc[:, (qld_australia_df_t.columns.str.contains(a) & qld_australia_df_t.columns.str.contains(b) & qld_australia_df_t.columns.str.contains(c))]
filter_df["All Industries_Other_All ages"] = pd.to_numeric(filter_df["All Industries_Other_All ages"])
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
newcol = [a for a in list(filter_df["All Industries_Other_All ages"][:-1])]
newcol.insert(0,0)
filter_df["last_val"] = newcol
filter_df["diff"] = (filter_df["All Industries_Other_All ages"] - filter_df["last_val"])/(filter_df["last_val"]) * 100
filter_df = filter_df.drop(["4-Jan-20","11-Jan-20","18-Jan-20","25-Jan-20","1-Feb-20","8-Feb-20","15-Feb-20","22-Feb-20","29-Feb-20","7-Mar-20"])
filter_df.to_csv("qld_percent_change_australia.csv", index=False, header=True)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
